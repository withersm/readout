# %%
import matplotlib.pyplot as plt
import sys
sys.path.append('/home/matt/readout/host/')
import ali_offline_demod as dm
import imp
imp.reload(dm)
import numpy as np
import pandas as pd
import glob as glob
# Out:
# /tmp/ipykernel_1362127/659104273.py:5: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   import imp

# %% [markdown]
# ## Examples

# %%
test_iv_1 = 'toneinit_fcenter_4250.0_20240202151540_t_20240202155930'

result_1 = dm.full_iv_process(test_iv_1,f_sawtooth=5,iv_path = '/home/matt/alicpt_data/IV_data', plot=None)
# Out:
# Delay Region Start (GHz):  4.02
# Delay Region Stop (GHz):  4.03
# 3.372806407385219
# (233, 188)

# %%
channel = 17
# %matplotlib qt
plt.plot(result_1['Vtes'][channel], result_1['Ites'][channel])

# %%
#0.1 Rn test

test_iv = 'toneinit_fcenter_4250.0_20240205135358_t_20240205135852'
result = dm.full_iv_process(test_iv_1,f_sawtooth=5,iv_path = '/home/matt/alicpt_data/IV_data', plot=None)
# Out:
# Delay Region Start (GHz):  4.02
# Delay Region Stop (GHz):  4.03
# 3.372806407385219
# (233, 188)

# %%
# %matplotlib inline
for ch in [22]:#range(result['bps'].shape[0]):
    if result['Rn Al'][ch] > 0.05 and result['Rn Al'][ch] < 0.005:
        continue
    else:
        plt.plot(result['Ibias'], result['bps'][ch],alpha=1)
        #plt.ylim([0,1.2])

# %%
file = 'ts_toneinit_fcenter_4250.0_20240205135358_t_20240205141913.hd5'

result_ts = dm.full_demod_process(file, f_sawtooth = 5)
# Out:
# Delay Region Start (GHz):  4.02
# Delay Region Stop (GHz):  4.03
# 3.3743971902426315

# %%
# %matplotlib qt
channel = 207

print(result_ts['demod data'].shape[0])

for ch in [19]:#range(result_ts['demod data'].shape[0]):
    plt.plot(result_ts['demod t'],result_ts['demod data'][ch],'o-',alpha=1)
    plt.ylabel('$N_{\Phi_0}$')
    plt.xlabel('t (s)')
# Out:
# 234

# %%
file = 'ts_toneinit_fcenter_4250.0_20240205135358_t_20240205145148.hd5'

result_ts_2 = dm.full_demod_process(file, f_sawtooth = 10)
# Out:
# Delay Region Start (GHz):  4.02
# Delay Region Stop (GHz):  4.03
# 3.471890404214844

# %%
# %matplotlib qt
for ch in [19]:#range(result_ts_2['demod data'].shape[0]):
    plt.plot(result_ts_2['demod t'],result_ts_2['demod data'][ch],'o-',alpha=1)
    plt.ylabel('$N_{\Phi_0}$')
    plt.xlabel('t (s)')

# %%
file = 'ts_toneinit_fcenter_4250.0_20240205135358_t_20240205150208.hd5'

result_ts_3 = dm.full_demod_process(file, f_sawtooth = 10)
# Out:
# Delay Region Start (GHz):  4.02
# Delay Region Stop (GHz):  4.03
# 3.476653238507319

# %%
# %matplotlib qt
for ch in range(result_ts_3['demod data'].shape[0]):
    plt.plot(result_ts_3['demod t'],result_ts_3['demod data'][ch],'o-',alpha=0.1)
    plt.ylabel('$N_{\Phi_0}$')
    plt.xlabel('t (s)')

# %%
file = 'ts_toneinit_fcenter_4250.0_20240205135358_t_20240205151302.hd5'

result_ts_4 = dm.full_demod_process(file, f_sawtooth = 15)
# Out:
# Delay Region Start (GHz):  4.02
# Delay Region Stop (GHz):  4.03
# bad channel 25
# bad channel 141
# bad channel 145
# bad channel 153
# bad channel 156
# bad channel 160
# bad channel 174
# bad channel 178
# bad channel 187
# bad channel 196
# bad channel 206
# bad channel 224
# bad channel 227
# bad channel 228
# 3.2538198969775958

# %%
# %matplotlib qt
for ch in [15,16,17,19]:#range(result_ts_4['demod data'].shape[0]):
    plt.plot(result_ts_4['demod t'],result_ts_4['demod data'][ch],'o-',alpha=0.1)
    plt.ylabel('$N_{\Phi_0}$')
    plt.xlabel('t (s)')

# %%
file = 'ts_toneinit_fcenter_4250.0_20240205135358_t_20240205152046.hd5'

result_ts_5 = dm.full_demod_process(file, f_sawtooth = 15)
# Out:
# Delay Region Start (GHz):  4.02
# Delay Region Stop (GHz):  4.03
# bad channel 25
# bad channel 141
# bad channel 145
# bad channel 153
# bad channel 156
# bad channel 160
# bad channel 174
# bad channel 178
# bad channel 187
# bad channel 196
# bad channel 206
# bad channel 224
# bad channel 227
# bad channel 228
# 3.2333518356936937

# %%
# %matplotlib qt
for ch in [15,16,17,18,19]:#range(result_ts_4['demod data'].shape[0]):
    plt.plot(result_ts_5['demod t'],result_ts_5['demod data'][ch],'o-',alpha=0.5)
    plt.ylabel('$N_{\Phi_0}$')
    plt.xlabel('t (s)')

# %%
file = 'ts_toneinit_fcenter_4250.0_20240205135358_t_20240205160326.hd5'

result_ts_6 = dm.full_demod_process(file, f_sawtooth = 15)
# Out:
# Delay Region Start (GHz):  4.02
# Delay Region Stop (GHz):  4.03
# bad channel 25
# bad channel 43
# bad channel 73
# bad channel 125
# bad channel 141
# bad channel 145
# bad channel 153
# bad channel 156
# bad channel 160
# bad channel 174
# bad channel 178
# bad channel 179
# bad channel 187
# bad channel 190
# bad channel 196
# bad channel 199
# bad channel 200
# bad channel 206
# bad channel 212
# bad channel 216
# bad channel 219
# bad channel 224
# bad channel 227
# bad channel 228
# bad channel 230
# 3.249207123877695

# %%
# %matplotlib qt
for ch in [15,16,17,18,19]:#range(result_ts_4['demod data'].shape[0]):
    plt.plot(result_ts_6['demod t'],result_ts_6['demod data'][ch],'o-',alpha=0.5)
    plt.ylabel('$N_{\Phi_0}$')
    plt.xlabel('t (s)')

# %% [markdown]
# ## 2024-02-06

# %%
#4.75 GHz, ASU 7

test_iv = 'toneinit_fcenter_4750.0_20240206134226_t_20240206145615'

result = dm.full_iv_process(test_iv,f_sawtooth=15,iv_path = '/home/matt/alicpt_data/IV_data', plot=None)

# %matplotlib qt
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])
    plt.xlabel('$V_{TES}$ (V)')
    plt.ylabel('$I_{TES}$ (mA)')
# Out:
# Delay Region Start (GHz):  4.89
# Delay Region Stop (GHz):  4.91
# bad channel 10
# bad channel 11
# bad channel 16
# bad channel 19
# bad channel 23
# bad channel 24
# bad channel 36
# bad channel 43
# bad channel 50
# bad channel 67
# bad channel 69
# bad channel 79
# bad channel 82
# bad channel 86
# bad channel 89
# bad channel 92
# 3.223901569177995
# (160, 188)

# %%
#4.75 GHz, ASU 9

test_iv = 'toneinit_fcenter_4750.0_20240206161036_t_20240206161558'

result = dm.full_iv_process(test_iv,f_sawtooth=15,iv_path = '/home/matt/alicpt_data/IV_data', plot=None)

# %matplotlib inline
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])
# Out:
# Delay Region Start (GHz):  4.9
# Delay Region Stop (GHz):  4.92
# bad channel 20
# bad channel 44
# bad channel 60
# bad channel 69
# bad channel 73
# bad channel 86
# bad channel 89
# bad channel 92
# bad channel 104
# bad channel 120
# bad channel 125
# bad channel 128
# bad channel 136
# bad channel 141
# bad channel 152
# 3.2355966982951476
# (160, 187)
# 94
# 20
# 93
# 119
# 95
# 95
# 114
# 94
# 94
# 95
# 96
# 94
# 94
# 94
# 95
# 94
# 94
# 95
# 95
# 95
# 97
# 93
# 94
# 94
# 96
# 96
# 94
# 163
# 93
# 93
# 95
# 96
# 96
# 100
# 119
# 119
# 119
# 119
# 119
# 119
# 64
# 64
# 94
# 95
# 97
# 98
# 117
# 119
# 119
# 119
# 95
# 32
# 48
# 119
# 119
# 96
# 93
# 95
# 96
# 119
# 119
# 119
# 119
# 69
# 119
# 119
# 119
# 119
# 119
# 93
# 93
# 95
# 97
# 98
# 119
# 119
# 68
# 64
# 119
# 57
# 119
# 47
# 119
# 119
# 119
# 119
# 64
# 119
# 119
# 55
# 64
# 119
# 119
# 49
# 103
# 119
# 119
# 32
# 119
# 119
# 55
# 69
# 69
# 119
# 125
# 119
# 119
# 119
# 119
# 119
# 119
# 119
# 56
# 119
# 119
# 119
# ...

# %%
# %matplotlib qt
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])

# %%
print(len(result['Rn Al']))
print(len(result['demod data']['channel freqs']))



#active_channel_chart = [result['Rn Al'],result['demod data']['channel freqs']]

active_channel_chart = pd.DataFrame({'Channel Freq (Hz)': result['demod data']['channel freqs'], 'Rn Al (mOhm)': result['Rn Al']})
active_channel_chart.to_csv('test_file.csv',sep=',')




print(active_channel_chart)
# Out:
# 160
# 160
#               Channel Freq (Hz)  Rn Al (mOhm)
# 0    4.500655e+09+0.000000e+00j      0.013457
# 1    4.534620e+09+0.000000e+00j           NaN
# 2    4.536804e+09+0.000000e+00j      0.011437
# 3    4.539176e+09+0.000000e+00j      0.013500
# 4    4.540836e+09+0.000000e+00j           NaN
# ..                          ...           ...
# 155  4.856113e+09+0.000000e+00j           NaN
# 156  4.858327e+09+0.000000e+00j           NaN
# 157  4.860528e+09+0.000000e+00j           NaN
# 158  4.862746e+09+0.000000e+00j           NaN
# 159  4.865228e+09+0.000000e+00j           NaN
#
# [160 rows x 2 columns]

# %%
def get_channel_response_summary(IV_analysis_result,filepath=None):
    active_channel_chart = pd.DataFrame({'Channel Freq (Hz)': IV_analysis_result['demod data']['channel freqs'].real, 'Rn Al (mOhm)': IV_analysis_result['Rn Al']})
    if filepath != None:
        active_channel_chart.to_csv(filepath,sep=',')
    return active_channel_chart

# %%
chart = get_channel_response_summary(result,filepath='./test_file_2.csv')

print(chart)
# Out:
#      Channel Freq (Hz)  Rn Al (mOhm)
# 0         4.500655e+09      0.013457
# 1         4.534620e+09           NaN
# 2         4.536804e+09      0.011437
# 3         4.539176e+09      0.013500
# 4         4.540836e+09           NaN
# ..                 ...           ...
# 155       4.856113e+09           NaN
# 156       4.858327e+09           NaN
# 157       4.860528e+09           NaN
# 158       4.862746e+09           NaN
# 159       4.865228e+09           NaN
#
# [160 rows x 2 columns]

# %%
#4.75 GHz, ASU 10

test_iv = 'toneinit_fcenter_4750.0_20240206161036_t_20240206162620'

result = dm.full_iv_process(test_iv,f_sawtooth=15,iv_path = '/home/matt/alicpt_data/IV_data', plot=None)

# %matplotlib inline
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])
# Out:
# Delay Region Start (GHz):  4.9
# Delay Region Stop (GHz):  4.902
# bad channel 3
# bad channel 11
# bad channel 20
# bad channel 25
# bad channel 44
# bad channel 50
# bad channel 59
# bad channel 60
# bad channel 69
# bad channel 73
# bad channel 80
# bad channel 86
# bad channel 89
# bad channel 92
# bad channel 103
# bad channel 104
# bad channel 109
# bad channel 120
# bad channel 123
# bad channel 125
# bad channel 127
# bad channel 128
# bad channel 136
# bad channel 141
# bad channel 152
# bad channel 158
# 3.2549277753964008
# (160, 188)

# %%
#4.75 GHz, ASU 11

test_iv = 'toneinit_fcenter_4750.0_20240206161036_t_20240206163646'

result = dm.full_iv_process(test_iv,f_sawtooth=15,iv_path = '/home/matt/alicpt_data/IV_data', plot=None)

# %matplotlib inline
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])
# Out:
# Delay Region Start (GHz):  4.9
# Delay Region Stop (GHz):  4.902
# bad channel 3
# bad channel 11
# bad channel 12
# bad channel 20
# bad channel 24
# bad channel 25
# bad channel 44
# bad channel 50
# bad channel 59
# bad channel 60
# bad channel 69
# bad channel 73
# bad channel 80
# bad channel 86
# bad channel 89
# bad channel 92
# bad channel 103
# bad channel 104
# bad channel 109
# bad channel 120
# bad channel 123
# bad channel 125
# bad channel 127
# bad channel 128
# bad channel 136
# bad channel 141
# bad channel 152
# 3.2531574242662216
# (160, 187)

# %%
#5.25 GHz, ASU 7

test_iv = 'toneinit_fcenter_5250.0_20240206164912_t_20240206165530'

result = dm.full_iv_process(test_iv,f_sawtooth=15,iv_path = '/home/matt/alicpt_data/IV_data', plot=None)

# %matplotlib inline
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])
# Out:
# Delay Region Start (GHz):  5.2
# Delay Region Stop (GHz):  5.202
# bad channel 2
# bad channel 11
# bad channel 15
# bad channel 19
# bad channel 22
# bad channel 23
# bad channel 37
# bad channel 40
# bad channel 41
# bad channel 42
# bad channel 45
# bad channel 47
# bad channel 48
# bad channel 49
# bad channel 53
# bad channel 56
# bad channel 57
# bad channel 58
# bad channel 71
# bad channel 86
# bad channel 87
# bad channel 95
# bad channel 120
# bad channel 121
# bad channel 128
# bad channel 129
# bad channel 130
# bad channel 131
# bad channel 132
# bad channel 133
# bad channel 134
# bad channel 135
# bad channel 136
# bad channel 137
# bad channel 138
# bad channel 139
# bad channel 140
# bad channel 141
# bad channel 142
# bad channel 144
# bad channel 145
# bad channel 148
# bad channel 159
# bad channel 165
# bad channel 166
# bad channel 172
# bad channel 189
# bad channel 198
# bad channel 213
# bad channel 214
# 3.226161245141379
# (232, 188)

# %%
#5.25 GHz, ASU 8

test_iv = 'toneinit_fcenter_5250.0_20240206164912_t_20240206170528'

result = dm.full_iv_process(test_iv,f_sawtooth=15,iv_path = '/home/matt/alicpt_data/IV_data', plot=None)

# %matplotlib inline
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])
# Out:
# Delay Region Start (GHz):  5.2
# Delay Region Stop (GHz):  5.202
# bad channel 2
# bad channel 11
# bad channel 15
# bad channel 19
# bad channel 22
# bad channel 23
# bad channel 37
# bad channel 40
# bad channel 42
# bad channel 45
# bad channel 47
# bad channel 48
# bad channel 49
# bad channel 53
# bad channel 56
# bad channel 57
# bad channel 58
# bad channel 71
# bad channel 86
# bad channel 87
# bad channel 95
# bad channel 120
# bad channel 121
# bad channel 128
# bad channel 129
# bad channel 130
# bad channel 131
# bad channel 132
# bad channel 133
# bad channel 134
# bad channel 135
# bad channel 136
# bad channel 137
# bad channel 138
# bad channel 139
# bad channel 140
# bad channel 141
# bad channel 142
# bad channel 144
# bad channel 145
# bad channel 148
# bad channel 159
# bad channel 165
# bad channel 166
# bad channel 172
# bad channel 189
# bad channel 198
# bad channel 202
# bad channel 213
# bad channel 214
# 3.081598114271622
# (232, 187)
# ...

# %%
#5.25 GHz, ASU 9

test_iv = 'toneinit_fcenter_5250.0_20240206164912_t_20240206171541'

result = dm.full_iv_process(test_iv,f_sawtooth=15,iv_path = '/home/matt/alicpt_data/IV_data', plot=None)

# %matplotlib inline
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])
# Out:
# Delay Region Start (GHz):  5.2
# Delay Region Stop (GHz):  5.202
# bad channel 2
# bad channel 11
# bad channel 15
# bad channel 19
# bad channel 22
# bad channel 23
# bad channel 37
# bad channel 40
# bad channel 41
# bad channel 42
# bad channel 45
# bad channel 47
# bad channel 48
# bad channel 49
# bad channel 53
# bad channel 56
# bad channel 57
# bad channel 58
# bad channel 71
# bad channel 86
# bad channel 87
# bad channel 128
# bad channel 129
# bad channel 130
# bad channel 131
# bad channel 132
# bad channel 133
# bad channel 134
# bad channel 135
# bad channel 136
# bad channel 138
# bad channel 139
# bad channel 140
# bad channel 141
# bad channel 142
# bad channel 144
# bad channel 145
# bad channel 189
# bad channel 198
# bad channel 213
# bad channel 214
# bad channel 221
# 2.9687146929161887
# (232, 187)

# %%
#5.25 GHz, ASU 10

test_iv = 'toneinit_fcenter_5250.0_20240206164912_t_20240206172543'

result = dm.full_iv_process(test_iv,f_sawtooth=15,iv_path = '/home/matt/alicpt_data/IV_data', plot=None)

# %matplotlib inline
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])
# Out:
# Delay Region Start (GHz):  5.2
# Delay Region Stop (GHz):  5.202
# bad channel 2
# bad channel 11
# bad channel 15
# bad channel 19
# bad channel 22
# bad channel 23
# bad channel 37
# bad channel 40
# bad channel 41
# bad channel 42
# bad channel 45
# bad channel 47
# bad channel 48
# bad channel 49
# bad channel 53
# bad channel 56
# bad channel 57
# bad channel 58
# bad channel 71
# bad channel 86
# bad channel 87
# bad channel 95
# bad channel 120
# bad channel 121
# bad channel 128
# bad channel 129
# bad channel 130
# bad channel 131
# bad channel 132
# bad channel 133
# bad channel 134
# bad channel 135
# bad channel 136
# bad channel 137
# bad channel 138
# bad channel 139
# bad channel 140
# bad channel 141
# bad channel 142
# bad channel 143
# bad channel 144
# bad channel 145
# bad channel 148
# bad channel 159
# bad channel 165
# bad channel 166
# bad channel 189
# bad channel 213
# bad channel 214
# bad channel 221
# 3.221171871700055
# (232, 188)
# ...

# %%
#5.25 GHz, ASU 11

test_iv = 'toneinit_fcenter_5250.0_20240206164912_t_20240206173752'

result = dm.full_iv_process(test_iv,f_sawtooth=15,iv_path = '/home/matt/alicpt_data/IV_data', plot=None)

# %matplotlib inline
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])
# Out:
# Delay Region Start (GHz):  5.2
# Delay Region Stop (GHz):  5.202
# bad channel 22
# bad channel 37
# bad channel 40
# bad channel 42
# bad channel 45
# bad channel 47
# bad channel 48
# bad channel 49
# bad channel 53
# bad channel 56
# bad channel 57
# bad channel 58
# bad channel 95
# bad channel 121
# bad channel 128
# bad channel 129
# bad channel 130
# bad channel 131
# bad channel 132
# bad channel 133
# bad channel 134
# bad channel 135
# bad channel 136
# bad channel 137
# bad channel 138
# bad channel 139
# bad channel 140
# bad channel 141
# bad channel 142
# bad channel 144
# bad channel 145
# bad channel 148
# bad channel 158
# bad channel 159
# bad channel 165
# bad channel 166
# bad channel 172
# bad channel 189
# bad channel 198
# bad channel 213
# bad channel 214
# 3.2283495354869496
# (232, 187)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ...

# %%
#5.75 GHz, ASU 8

test_iv = 'toneinit_fcenter_5750.0_20240206174822_t_20240206175536'

result = dm.full_iv_process(test_iv,f_sawtooth=15,iv_path = '/home/matt/alicpt_data/IV_data', plot=None)

# %matplotlib inline
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])
# Out:
# Delay Region Start (GHz):  5.89
# Delay Region Stop (GHz):  5.91
# bad channel 8
# bad channel 10
# bad channel 12
# bad channel 14
# bad channel 16
# bad channel 18
# bad channel 19
# bad channel 22
# bad channel 23
# bad channel 24
# bad channel 25
# bad channel 28
# bad channel 31
# bad channel 34
# bad channel 35
# bad channel 37
# bad channel 39
# bad channel 41
# bad channel 53
# bad channel 56
# bad channel 61
# bad channel 64
# bad channel 69
# bad channel 70
# bad channel 73
# bad channel 81
# bad channel 84
# bad channel 85
# bad channel 89
# bad channel 98
# bad channel 101
# bad channel 102
# bad channel 105
# bad channel 118
# bad channel 136
# bad channel 140
# bad channel 154
# bad channel 162
# bad channel 164
# bad channel 182
# 3.2534886271466315
# (210, 187)
# /home/matt/readout/host/ali_offline_demod.py:694: RankWarning: Polyfit may be poorly conditioned
# ...

# %%
#5.75 GHz, ASU 9

test_iv = 'toneinit_fcenter_5750.0_20240206174822_t_20240206180601'

result = dm.full_iv_process(test_iv,f_sawtooth=15,iv_path = '/home/matt/alicpt_data/IV_data', plot=None)

# %matplotlib inline
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])
# Out:
# /home/matt/readout/host/ali_offline_demod.py:507: RuntimeWarning: divide by zero encountered in log10
#   mag = 20* np.log10(np.abs(sweep_Z))
# /home/matt/.local/readout/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Delay Region Start (GHz):  5.89
# Delay Region Stop (GHz):  5.91
# bad channel 8
# bad channel 10
# bad channel 12
# bad channel 14
# bad channel 16
# bad channel 18
# bad channel 19
# bad channel 22
# bad channel 23
# bad channel 24
# bad channel 25
# bad channel 28
# bad channel 31
# bad channel 34
# bad channel 35
# bad channel 37
# bad channel 39
# bad channel 41
# bad channel 53
# bad channel 56
# bad channel 61
# bad channel 64
# bad channel 69
# bad channel 70
# bad channel 73
# bad channel 81
# bad channel 84
# bad channel 85
# bad channel 89
# bad channel 98
# bad channel 101
# bad channel 102
# bad channel 105
# bad channel 118
# ...

# %%
#5.75 GHz, ASU 11

test_iv = 'toneinit_fcenter_5750.0_20240206174822_t_20240206181946'

result = dm.full_iv_process(test_iv,f_sawtooth=15,iv_path = '/home/matt/alicpt_data/IV_data', plot=None)

# %matplotlib inline
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])
# Out:
# Delay Region Start (GHz):  5.89
# Delay Region Stop (GHz):  5.91
# bad channel 8
# bad channel 10
# bad channel 12
# bad channel 14
# bad channel 16
# bad channel 18
# bad channel 19
# bad channel 22
# bad channel 23
# bad channel 24
# bad channel 25
# bad channel 28
# bad channel 31
# bad channel 34
# bad channel 35
# bad channel 37
# bad channel 39
# bad channel 41
# bad channel 53
# bad channel 56
# bad channel 61
# bad channel 64
# bad channel 69
# bad channel 70
# bad channel 73
# bad channel 81
# bad channel 84
# bad channel 85
# bad channel 89
# bad channel 98
# bad channel 101
# bad channel 102
# bad channel 170
# bad channel 171
# bad channel 172
# bad channel 176
# bad channel 178
# bad channel 180
# bad channel 182
# bad channel 183
# bad channel 185
# bad channel 188
# bad channel 193
# bad channel 196
# bad channel 198
# bad channel 201
# 3.2363456859489577
# (210, 187)
# ---------------------------------------------------------------------------
# ...

# %%
#5.75 GHz, ASU 12

test_iv = 'toneinit_fcenter_5750.0_20240206174822_t_20240206183001'

result = dm.full_iv_process(test_iv,f_sawtooth=15,iv_path = '/home/matt/alicpt_data/IV_data', plot=None)

# %matplotlib inline
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])
# Out:
# Delay Region Start (GHz):  5.89
# Delay Region Stop (GHz):  5.91
# bad channel 16
# bad channel 23
# bad channel 39
# bad channel 41
# bad channel 53
# bad channel 56
# bad channel 61
# bad channel 64
# bad channel 69
# bad channel 70
# bad channel 73
# bad channel 81
# bad channel 84
# bad channel 85
# bad channel 89
# bad channel 98
# bad channel 101
# bad channel 102
# bad channel 105
# bad channel 118
# bad channel 136
# bad channel 154
# bad channel 162
# bad channel 164
# bad channel 170
# bad channel 171
# bad channel 172
# bad channel 176
# bad channel 178
# bad channel 180
# bad channel 182
# bad channel 183
# bad channel 185
# bad channel 188
# bad channel 193
# bad channel 196
# bad channel 198
# 3.233407918345793
# (210, 188)

# %% [markdown]
# ## 2024-02-07

# %%
#4.25 GHz, ASU 9
# %matplotlib inline

test_iv = 'toneinit_fcenter_4250.0_20240207130021_t_20240207130454'

result = dm.full_iv_process(test_iv,f_sawtooth=15,iv_path = '/home/matt/alicpt_data/IV_data', filter_Rn_Al=True, plot='orgorg')
# Out:
# Delay Region Start (GHz):  4.01
# Delay Region Stop (GHz):  4.02
# 3.2298131576354345
# (233, 187)
# (82,)
# (82,)
# (41,)
# (41,)
# 0.008003147135317306
# 0.012221028028781224
# (80,)
# (80,)
# (152,)
# (152,)
# 0.009181673155338715
# 0.009588786036496908
# (82,)
# (82,)
# (0,)
# (0,)
# 0.00725
# 0.010987128256699293
# (82,)
# (82,)
# (42,)
# (42,)
# 0.007600351076515229
# 0.011374286013305736
# (83,)
# (83,)
# (44,)
# (44,)
# 0.00758307668736844
# 0.011314796442926541
# (82,)
# (82,)
# (43,)
# (43,)
# 0.007615544413991056
# 0.011338936564840627
# (82,)
# (82,)
# (0,)
# (0,)
# 0.00725
# 0.01210426705687169
# (82,)
# (82,)
# (41,)
# (41,)
# 0.007611846738961447
# 0.011406235128167325
# (83,)
# (83,)
# (40,)
# (40,)
# 0.007553029287176382
# 0.011254087665169901
# (82,)
# (82,)
# (42,)
# (42,)
# 0.007901549103876287
# 0.012017476357410305
# (86,)
# (86,)
# (40,)
# (40,)
# 0.008123796246150585
# 0.01246881229468624
# (84,)
# (84,)
# (41,)
# (41,)
# 0.007583139720898653
# ...

# %%
path = '/home/matt/readout/jupyter_notebooks/improve_iv_test_data/'

np.save(path+'demod_data.npy',result['demod data'])
np.save(path+'bias_currents.npy',result['Ibias'])

# %%
# %matplotlib qt
plt.figure(figsize=(11,8))
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])
plt.xlabel('$V_{TES}$ (μV)',fontsize=24)
plt.ylabel('$I_{TES}$ (mA)',fontsize=24)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title('LO = 4250 MHz; Bias Line = 8',fontsize=26)
    
    
chart = dm.get_channel_response_summary(result,'./4250MHz_ASU9.csv')
print(chart)
# Out:
#      Channel Freq (Hz)  Rn Al (mOhm)
# 0         4.044545e+09           NaN
# 1         4.049245e+09           NaN
# 2         4.051184e+09           NaN
# 3         4.053305e+09           NaN
# 4         4.055906e+09           NaN
# ..                 ...           ...
# 228       4.485795e+09      0.011096
# 229       4.488090e+09      0.011207
# 230       4.490202e+09      0.011416
# 231       4.492544e+09           NaN
# 232       4.495425e+09      0.012261
#
# [233 rows x 2 columns]

# %%
count = 0
sum_var = 0
for i in range(len(result['Rn Al'])):
    if ~np.isnan(result['Rn Al'][i]):
        sum_var += result['Rn Al'][i]
        count += 1
        
final_Rn = sum_var/count
print(final_Rn*1e3)
# Out:
# 12.426485925578534

# %%
#4.25 GHz, ASU 10
# %matplotlib inline

test_iv = 'toneinit_fcenter_4250.0_20240207132916_t_20240207133356'

result = dm.full_iv_process(test_iv,f_sawtooth=15,iv_path = '/home/matt/alicpt_data/IV_data', filter_Rn_Al=True, plot=None)
# Out:
# /home/matt/readout/host/ali_offline_demod.py:509: RuntimeWarning: divide by zero encountered in log10
#   mag = 20* np.log10(np.abs(sweep_Z))
# /home/matt/.local/readout/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Delay Region Start (GHz):  4.01
# Delay Region Stop (GHz):  4.03
# 3.2178356751863317
# (231, 188)

# %%
# %matplotlib qt
plt.figure(figsize=(11,8))
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])
    
plt.xlabel('$V_{TES}$ (μV)',fontsize=24)
plt.ylabel('$I_{TES}$ (mA)',fontsize=24)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title('LO = 4250 MHz; Bias Line = 9',fontsize=26)
    
chart = dm.get_channel_response_summary(result,'./4250MHz_ASU10.csv')
print(chart)
# Out:
#      Channel Freq (Hz)  Rn Al (mOhm)
# 0         4.044545e+09           NaN
# 1         4.049260e+09      0.012569
# 2         4.051177e+09      0.012696
# 3         4.053299e+09      0.015492
# 4         4.055897e+09      0.013583
# ..                 ...           ...
# 226       4.484572e+09           NaN
# 227       4.485820e+09           NaN
# 228       4.488091e+09           NaN
# 229       4.490253e+09           NaN
# 230       4.492509e+09           NaN
#
# [231 rows x 2 columns]

# %%
#4.25 GHz, ASU 11
# %matplotlib inline

test_iv = 'toneinit_fcenter_4250.0_20240207132916_t_20240207134323'

result = dm.full_iv_process(test_iv,f_sawtooth=15,iv_path = '/home/matt/alicpt_data/IV_data', filter_Rn_Al=True, plot=None)
# Out:
# /home/matt/readout/host/ali_offline_demod.py:509: RuntimeWarning: divide by zero encountered in log10
#   mag = 20* np.log10(np.abs(sweep_Z))
# /home/matt/.local/readout/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Delay Region Start (GHz):  4.01
# Delay Region Stop (GHz):  4.03
# 3.2347357989272316
# (231, 187)

# %%
# %matplotlib qt
plt.figure(figsize=(11,8))
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])
    
plt.xlabel('$V_{TES}$ (μV)',fontsize=24)
plt.ylabel('$I_{TES}$ (mA)',fontsize=24)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title('LO = 4250 MHz; Bias Line = 10',fontsize=26)
    
chart = dm.get_channel_response_summary(result,'./4250MHz_ASU11.csv')
print(chart)
# Out:
#      Channel Freq (Hz)  Rn Al (mOhm)
# 0         4.044545e+09           NaN
# 1         4.049260e+09           NaN
# 2         4.051177e+09           NaN
# 3         4.053299e+09           NaN
# 4         4.055897e+09           NaN
# ..                 ...           ...
# 226       4.484572e+09           NaN
# 227       4.485820e+09           NaN
# 228       4.488091e+09           NaN
# 229       4.490253e+09           NaN
# 230       4.492509e+09           NaN
#
# [231 rows x 2 columns]

# %%
#4.75 GHz, ASU 7
# %matplotlib inline

test_iv = 'toneinit_fcenter_4750.0_20240207135323_t_20240207135723'

result = dm.full_iv_process(test_iv,f_sawtooth=15,iv_path = '/home/matt/alicpt_data/IV_data', filter_Rn_Al=True, plot=None)
# Out:
# /home/matt/readout/host/ali_offline_demod.py:509: RuntimeWarning: divide by zero encountered in log10
#   mag = 20* np.log10(np.abs(sweep_Z))
# Delay Region Start (GHz):  4.9
# Delay Region Stop (GHz):  4.92
# 3.2221740800491663
# (161, 188)

# %%
# %matplotlib qt
plt.figure(figsize=(11,8))
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])
    
plt.xlabel('$V_{TES}$ (μV)',fontsize=24)
plt.ylabel('$I_{TES}$ (mA)',fontsize=24)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title('LO = 4750 MHz; Bias Line = 6',fontsize=26)
    
chart = dm.get_channel_response_summary(result,'./4750MHz_ASU7.csv')
print(chart)
# Out:
#      Channel Freq (Hz)  Rn Al (mOhm)
# 0         4.534634e+09           NaN
# 1         4.536828e+09           NaN
# 2         4.539223e+09           NaN
# 3         4.540860e+09           NaN
# 4         4.542409e+09           NaN
# ..                 ...           ...
# 156       4.856118e+09      0.013906
# 157       4.858346e+09      0.013937
# 158       4.860538e+09      0.015881
# 159       4.862738e+09      0.013878
# 160       4.865224e+09      0.014349
#
# [161 rows x 2 columns]

# %%
#4.75 GHz, ASU 8
# %matplotlib inline

test_iv = 'toneinit_fcenter_4750.0_20240207135323_t_20240207140517'

result = dm.full_iv_process(test_iv,f_sawtooth=15,iv_path = '/home/matt/alicpt_data/IV_data', filter_Rn_Al=True,plot=None)
# Out:
# /home/matt/readout/host/ali_offline_demod.py:511: RuntimeWarning: divide by zero encountered in log10
#   if labels != None:
# /home/matt/.local/readout/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Delay Region Start (GHz):  4.9
# Delay Region Stop (GHz):  4.92
# [[ 1.76513614e+17 -2.02274515e+13  3.38416087e+13  9.17081598e+09]
#  [-2.02274515e+13  2.53119087e+09 -3.75779679e+09 -1.06020617e+06]
#  [ 3.38416087e+13 -3.75779679e+09  6.63962511e+09  1.79691768e+06]
#  [ 9.17081598e+09 -1.06020617e+06  1.79691768e+06  5.00000000e+02]]
# [[ 0  0  0 -2]
#  [ 0  1  0  0]
#  [ 0  0  1  0]
#  [-2  0  0  0]]
# [[ 1.44501962e+17 -1.45687076e+13  3.05874148e+13  8.27909216e+09]
#  [-1.45687076e+13  1.66745775e+09 -2.97320812e+09 -8.34577301e+05]
#  [ 3.05874148e+13 -2.97320812e+09  6.61163441e+09  1.79646393e+06]
# ...

# %%
# %matplotlib qt
plt.figure(figsize=(11,8))
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])
    
plt.xlabel('$V_{TES}$ (μV)',fontsize=24)
plt.ylabel('$I_{TES}$ (mA)',fontsize=24)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title('LO = 4750 MHz; Bias Line = 7',fontsize=26)
    
chart = dm.get_channel_response_summary(result,'./4750MHz_ASU8.csv')
print(chart)
# Out:
#      Channel Freq (Hz)  Rn Al (mOhm)
# 0         4.534634e+09           NaN
# 1         4.536828e+09           NaN
# 2         4.539223e+09           NaN
# 3         4.540860e+09           NaN
# 4         4.542409e+09           NaN
# ..                 ...           ...
# 156       4.856118e+09           NaN
# 157       4.858346e+09           NaN
# 158       4.860538e+09           NaN
# 159       4.862738e+09           NaN
# 160       4.865224e+09           NaN
#
# [161 rows x 2 columns]

# %%
#4.75 GHz, ASU 11
# %matplotlib inline

test_iv = 'toneinit_fcenter_4750.0_20240207135323_t_20240207141244'

result = dm.full_iv_process(test_iv,f_sawtooth=15,iv_path = '/home/matt/alicpt_data/IV_data', filter_Rn_Al=True, plot=None)
# Out:
# /home/matt/readout/host/ali_offline_demod.py:511: RuntimeWarning: divide by zero encountered in log10
#   if labels != None:
# /home/matt/.local/readout/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Delay Region Start (GHz):  4.9
# Delay Region Stop (GHz):  4.92
# [[ 1.76513614e+17 -2.02274515e+13  3.38416087e+13  9.17081598e+09]
#  [-2.02274515e+13  2.53119087e+09 -3.75779679e+09 -1.06020617e+06]
#  [ 3.38416087e+13 -3.75779679e+09  6.63962511e+09  1.79691768e+06]
#  [ 9.17081598e+09 -1.06020617e+06  1.79691768e+06  5.00000000e+02]]
# [[ 0  0  0 -2]
#  [ 0  1  0  0]
#  [ 0  0  1  0]
#  [-2  0  0  0]]
# [[ 1.44501962e+17 -1.45687076e+13  3.05874148e+13  8.27909216e+09]
#  [-1.45687076e+13  1.66745775e+09 -2.97320812e+09 -8.34577301e+05]
#  [ 3.05874148e+13 -2.97320812e+09  6.61163441e+09  1.79646393e+06]
# ...

# %%
# %matplotlib qt
plt.figure(figsize=(11,8))
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])

plt.xlabel('$V_{TES}$ (μV)',fontsize=24)
plt.ylabel('$I_{TES}$ (mA)',fontsize=24)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title('LO = 4750 MHz; Bias Line = 10',fontsize=26)

chart = dm.get_channel_response_summary(result,'./4750MHz_ASU11.csv')
print(chart)
# Out:
#      Channel Freq (Hz)  Rn Al (mOhm)
# 0         4.534634e+09           NaN
# 1         4.536828e+09           NaN
# 2         4.539223e+09           NaN
# 3         4.540860e+09           NaN
# 4         4.542409e+09           NaN
# ..                 ...           ...
# 156       4.856118e+09           NaN
# 157       4.858346e+09           NaN
# 158       4.860538e+09           NaN
# 159       4.862738e+09           NaN
# 160       4.865224e+09           NaN
#
# [161 rows x 2 columns]

# %%
#4.75 GHz, ASU 9
# %matplotlib inline

test_iv = 'toneinit_fcenter_4750.0_20240207135323_t_20240207142011'

result = dm.full_iv_process(test_iv,f_sawtooth=15,iv_path = '/home/matt/alicpt_data/IV_data', filter_Rn_Al=True,plot=None)
# Out:
# /home/matt/readout/host/ali_offline_demod.py:509: RuntimeWarning: divide by zero encountered in log10
#   mag = 20* np.log10(np.abs(sweep_Z))
# /home/matt/.local/readout/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Delay Region Start (GHz):  4.9
# Delay Region Stop (GHz):  4.92
# 3.2300649970735913
# (161, 187)

# %%
# %matplotlib qt
plt.figure(figsize=(11,8))
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])
    
plt.xlabel('$V_{TES}$ (μV)',fontsize=24)
plt.ylabel('$I_{TES}$ (mA)',fontsize=24)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title('LO = 4750 MHz; Bias Line = 8',fontsize=26)
    
chart = dm.get_channel_response_summary(result,'./4750MHz_ASU9.csv')
print(chart)
# Out:
#      Channel Freq (Hz)  Rn Al (mOhm)
# 0         4.534634e+09      0.012848
# 1         4.536828e+09      0.012352
# 2         4.539223e+09      0.011984
# 3         4.540860e+09           NaN
# 4         4.542409e+09      0.011698
# ..                 ...           ...
# 156       4.856118e+09           NaN
# 157       4.858346e+09           NaN
# 158       4.860538e+09           NaN
# 159       4.862738e+09           NaN
# 160       4.865224e+09           NaN
#
# [161 rows x 2 columns]

# %%
#5.25 GHz, ASU 7
# %matplotlib inline

test_iv = 'toneinit_fcenter_5250.0_20240207142816_t_20240207143415'

result = dm.full_iv_process(test_iv,f_sawtooth=15,iv_path = '/home/matt/alicpt_data/IV_data', filter_Rn_Al=True,plot=None)
# Out:
# /home/matt/readout/host/ali_offline_demod.py:509: RuntimeWarning: divide by zero encountered in log10
#   mag = 20* np.log10(np.abs(sweep_Z))
# /home/matt/.local/readout/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Delay Region Start (GHz):  5.2
# Delay Region Stop (GHz):  5.22
# 3.229113857020942
# (203, 188)

# %%
# %matplotlib qt
plt.figure(figsize=(11,8))
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])
    
plt.xlabel('$V_{TES}$ (μV)',fontsize=24)
plt.ylabel('$I_{TES}$ (mA)',fontsize=24)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title('LO = 5250 MHz; Bias Line = 6',fontsize=26)
    
chart = dm.get_channel_response_summary(result,'./5250MHz_ASU7.csv')
print(chart)
# Out:
#      Channel Freq (Hz)  Rn Al (mOhm)
# 0         5.046520e+09           NaN
# 1         5.051799e+09           NaN
# 2         5.053659e+09           NaN
# 3         5.055599e+09           NaN
# 4         5.057424e+09           NaN
# ..                 ...           ...
# 198       5.485464e+09           NaN
# 199       5.488355e+09           NaN
# 200       5.490317e+09           NaN
# 201       5.491353e+09           NaN
# 202       5.495999e+09           NaN
#
# [203 rows x 2 columns]

# %%
#5.25 GHz, ASU 9
# %matplotlib inline

test_iv = 'toneinit_fcenter_5250.0_20240207142816_t_20240207144221'

result = dm.full_iv_process(test_iv,f_sawtooth=15,iv_path = '/home/matt/alicpt_data/IV_data', filter_Rn_Al=True,plot=None)
# Out:
# /home/matt/readout/host/ali_offline_demod.py:509: RuntimeWarning: divide by zero encountered in log10
#   mag = 20* np.log10(np.abs(sweep_Z))
# /home/matt/.local/readout/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Delay Region Start (GHz):  5.2
# Delay Region Stop (GHz):  5.22
# 3.0291045176204694
# (203, 187)

# %%
# %matplotlib qt
plt.figure(figsize=(11,8))
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])
    
plt.xlabel('$V_{TES}$ (μV)',fontsize=24)
plt.ylabel('$I_{TES}$ (mA)',fontsize=24)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title('LO = 5250 MHz; Bias Line = 8',fontsize=26)
    
chart = dm.get_channel_response_summary(result,'./5250MHz_ASU9.csv')
print(chart)
# Out:
#      Channel Freq (Hz)  Rn Al (mOhm)
# 0         5.046520e+09           NaN
# 1         5.051799e+09           NaN
# 2         5.053659e+09           NaN
# 3         5.055599e+09           NaN
# 4         5.057424e+09           NaN
# ..                 ...           ...
# 198       5.485464e+09           NaN
# 199       5.488355e+09           NaN
# 200       5.490317e+09           NaN
# 201       5.491353e+09           NaN
# 202       5.495999e+09           NaN
#
# [203 rows x 2 columns]

# %%
#changed input attenuation to 10 dB
#5.25 GHz, ASU 7
# %matplotlib inline

test_iv = 'toneinit_fcenter_5250.0_20240207145944_t_20240207150411'

result = dm.full_iv_process(test_iv,f_sawtooth=15,iv_path = '/home/matt/alicpt_data/IV_data', filter_Rn_Al=True, plot=None)
# Out:
# /home/matt/readout/host/ali_offline_demod.py:509: RuntimeWarning: divide by zero encountered in log10
#   mag = 20* np.log10(np.abs(sweep_Z))
# /home/matt/.local/readout/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Delay Region Start (GHz):  5.2
# Delay Region Stop (GHz):  5.22
# 3.236945113292585
# (185, 188)

# %%
# %matplotlib qt
plt.figure(figsize=(11,8))
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])
    
plt.xlabel('$V_{TES}$ (μV)',fontsize=24)
plt.ylabel('$I_{TES}$ (mA)',fontsize=24)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title('LO = 5250 MHz; Bias Line = 6',fontsize=26)
    
chart = dm.get_channel_response_summary(result,'./5250MHz_ASU7.csv')
print(chart)
# Out:
#      Channel Freq (Hz)  Rn Al (mOhm)
# 0         5.046516e+09           NaN
# 1         5.051817e+09           NaN
# 2         5.053680e+09           NaN
# 3         5.055610e+09           NaN
# 4         5.057419e+09           NaN
# ..                 ...           ...
# 180       5.490311e+09           NaN
# 181       5.491326e+09           NaN
# 182       5.493474e+09           NaN
# 183       5.494587e+09           NaN
# 184       5.496031e+09           NaN
#
# [185 rows x 2 columns]

# %%
#changed input attenuation to 10 dB
#5.25 GHz, ASU 9
# %matplotlib inline

test_iv = 'toneinit_fcenter_5250.0_20240207145944_t_20240207151200'

result = dm.full_iv_process(test_iv,f_sawtooth=15,iv_path = '/home/matt/alicpt_data/IV_data', filter_Rn_Al=True, plot=None)
# Out:
# /home/matt/readout/host/ali_offline_demod.py:509: RuntimeWarning: divide by zero encountered in log10
#   mag = 20* np.log10(np.abs(sweep_Z))
# /home/matt/.local/readout/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Delay Region Start (GHz):  5.2
# Delay Region Stop (GHz):  5.22
# 3.2215708609812643
# (185, 187)

# %%
# %matplotlib qt
plt.figure(figsize=(11,8))
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])
    
plt.xlabel('$V_{TES}$ (μV)',fontsize=24)
plt.ylabel('$I_{TES}$ (mA)',fontsize=24)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title('LO = 5250 MHz; Bias Line = 8',fontsize=26)
    
chart = dm.get_channel_response_summary(result,'./5250MHz_ASU9.csv')
print(chart)
# Out:
#      Channel Freq (Hz)  Rn Al (mOhm)
# 0         5.046516e+09           NaN
# 1         5.051817e+09           NaN
# 2         5.053680e+09           NaN
# 3         5.055610e+09           NaN
# 4         5.057419e+09           NaN
# ..                 ...           ...
# 180       5.490311e+09           NaN
# 181       5.491326e+09           NaN
# 182       5.493474e+09           NaN
# 183       5.494587e+09      0.012689
# 184       5.496031e+09           NaN
#
# [185 rows x 2 columns]

# %%
#changed input attenuation to 10 dB
#5.25 GHz, ASU 12
# %matplotlib inline

test_iv = 'toneinit_fcenter_5250.0_20240207145944_t_20240207151932'

result = dm.full_iv_process(test_iv,f_sawtooth=15,iv_path = '/home/matt/alicpt_data/IV_data', filter_Rn_Al=True, plot=None)
# Out:
# /home/matt/readout/host/ali_offline_demod.py:509: RuntimeWarning: divide by zero encountered in log10
#   mag = 20* np.log10(np.abs(sweep_Z))
# /home/matt/.local/readout/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Delay Region Start (GHz):  5.2
# Delay Region Stop (GHz):  5.22
# 3.232454761244181
# (185, 188)

# %%
# %matplotlib qt
plt.figure(figsize=(11,8))
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])
    
plt.xlabel('$V_{TES}$ (μV)',fontsize=24)
plt.ylabel('$I_{TES}$ (mA)',fontsize=24)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title('LO = 5250 MHz; Bias Line = 11',fontsize=26)
    
chart = dm.get_channel_response_summary(result,'./5250MHz_ASU12.csv')
print(chart)
# Out:
#      Channel Freq (Hz)  Rn Al (mOhm)
# 0         5.046516e+09           NaN
# 1         5.051817e+09           NaN
# 2         5.053680e+09           NaN
# 3         5.055610e+09           NaN
# 4         5.057419e+09           NaN
# ..                 ...           ...
# 180       5.490311e+09      0.013417
# 181       5.491326e+09      0.012811
# 182       5.493474e+09      0.012354
# 183       5.494587e+09           NaN
# 184       5.496031e+09      0.014854
#
# [185 rows x 2 columns]

# %%
#changed input attenuation to 10 dB
#5.75 GHz, ASU 8
# %matplotlib inline

test_iv = 'toneinit_fcenter_5750.0_20240207152712_t_20240207153142'

result = dm.full_iv_process(test_iv,f_sawtooth=15,iv_path = '/home/matt/alicpt_data/IV_data', filter_Rn_Al=True, plot=None)
# Out:
# Delay Region Start (GHz):  5.89
# Delay Region Stop (GHz):  5.91
# 3.254056559794873
# (195, 187)

# %%
# %matplotlib qt
plt.figure(figsize=(11,8))
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])
    
plt.xlabel('$V_{TES}$ (μV)',fontsize=24)
plt.ylabel('$I_{TES}$ (mA)',fontsize=24)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title('LO = 5750 MHz; Bias Line = 7',fontsize=26)
    
chart = dm.get_channel_response_summary(result,'./5750MHz_ASU8.csv')
print(chart)
# Out:
#      Channel Freq (Hz)  Rn Al (mOhm)
# 0         5.501578e+09           NaN
# 1         5.503111e+09           NaN
# 2         5.543371e+09           NaN
# 3         5.545624e+09           NaN
# 4         5.547418e+09           NaN
# ..                 ...           ...
# 190       5.978706e+09      0.012681
# 191       5.979738e+09           NaN
# 192       5.991073e+09      0.013619
# 193       5.992738e+09           NaN
# 194       5.996423e+09      0.012291
#
# [195 rows x 2 columns]

# %%
#changed input attenuation to 10 dB
#5.75 GHz, ASU 11
# %matplotlib inline

test_iv = 'toneinit_fcenter_5750.0_20240207152712_t_20240207153916'

result = dm.full_iv_process(test_iv,f_sawtooth=15,iv_path = '/home/matt/alicpt_data/IV_data', filter_Rn_Al=True, plot=None)
# Out:
# /home/matt/readout/host/ali_offline_demod.py:509: RuntimeWarning: divide by zero encountered in log10
#   mag = 20* np.log10(np.abs(sweep_Z))
# /home/matt/.local/readout/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Delay Region Start (GHz):  5.89
# Delay Region Stop (GHz):  5.91
# 3.2316329086862092
# (195, 187)

# %%
# %matplotlib qt
plt.figure(figsize=(11,8))
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])
    
plt.xlabel('$V_{TES}$ (μV)',fontsize=24)
plt.ylabel('$I_{TES}$ (mA)',fontsize=24)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title('LO = 5750 MHz; Bias Line = 10',fontsize=26)
    
chart = dm.get_channel_response_summary(result,'./5750MHz_ASU11.csv')
print(chart)
# Out:
#      Channel Freq (Hz)  Rn Al (mOhm)
# 0         5.501578e+09           NaN
# 1         5.503111e+09           NaN
# 2         5.543371e+09           NaN
# 3         5.545624e+09           NaN
# 4         5.547418e+09           NaN
# ..                 ...           ...
# 190       5.978706e+09           NaN
# 191       5.979738e+09           NaN
# 192       5.991073e+09           NaN
# 193       5.992738e+09           NaN
# 194       5.996423e+09           NaN
#
# [195 rows x 2 columns]

# %%
#changed input attenuation to 10 dB
#6.25 GHz, ASU 8
# %matplotlib inline

test_iv = 'toneinit_fcenter_6250.0_20240207154701_t_20240207155142'

result = dm.full_iv_process(test_iv,f_sawtooth=15,iv_path = '/home/matt/alicpt_data/IV_data', filter_Rn_Al=True, plot=None)
# Out:
# /home/matt/readout/host/ali_offline_demod.py:509: RuntimeWarning: divide by zero encountered in log10
#   mag = 20* np.log10(np.abs(sweep_Z))
# /home/matt/.local/readout/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Delay Region Start (GHz):  6.2
# Delay Region Stop (GHz):  6.22
# 2.967800939761946
# (94, 187)

# %%
# %matplotlib qt
plt.figure(figsize=(11,8))
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])
    
plt.xlabel('$V_{TES}$ (μV)',fontsize=24)
plt.ylabel('$I_{TES}$ (mA)',fontsize=24)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title('LO = 6250 MHz; Bias Line = 7',fontsize=26)
    
chart = dm.get_channel_response_summary(result,'./6250MHz_ASU8.csv')
print(chart)
# Out:
#     Channel Freq (Hz)  Rn Al (mOhm)
# 0        6.000068e+09      0.012017
# 1        6.001905e+09      0.013645
# 2        6.003979e+09           NaN
# 3        6.005955e+09           NaN
# 4        6.008022e+09      0.012375
# ..                ...           ...
# 89       6.480928e+09           NaN
# 90       6.482462e+09      0.012540
# 91       6.484084e+09      0.012407
# 92       6.485528e+09           NaN
# 93       6.487604e+09           NaN
#
# [94 rows x 2 columns]

# %%
#changed input attenuation to 10 dB
#6.75 GHz, ASU 12
# %matplotlib inline

test_iv = 'toneinit_fcenter_6750.0_20240207155941_t_20240207160403'

result = dm.full_iv_process(test_iv,f_sawtooth=15,iv_path = '/home/matt/alicpt_data/IV_data', filter_Rn_Al=True, plot=None)
# Out:
# /home/matt/readout/host/ali_offline_demod.py:509: RuntimeWarning: divide by zero encountered in log10
#   mag = 20* np.log10(np.abs(sweep_Z))
# /home/matt/.local/readout/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Delay Region Start (GHz):  6.7
# Delay Region Stop (GHz):  6.72
# 2.9688407566668435
# (55, 188)

# %%
# %matplotlib qt
plt.figure(figsize=(11,8))
for ch in range(result['Ites'].shape[0]):
    plt.plot(result['Vtes'][ch], result['Ites'][ch])
    
plt.xlabel('$V_{TES}$ (μV)',fontsize=24)
plt.ylabel('$I_{TES}$ (mA)',fontsize=24)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title('LO = 6750 MHz; Bias Line = 11',fontsize=26)
    
chart = dm.get_channel_response_summary(result,'./6750MHz_ASU12.csv')
print(chart)
# Out:
#     Channel Freq (Hz)  Rn Al (mOhm)
# 0        6.761432e+09      0.011973
# 1        6.763070e+09      0.014644
# 2        6.764458e+09      0.013807
# 3        6.765783e+09      0.013672
# 4        6.769636e+09      0.014021
# 5        6.771354e+09      0.011821
# 6        6.772911e+09      0.011568
# 7        6.774722e+09      0.013632
# 8        6.776861e+09      0.013390
# 9        6.778160e+09      0.012697
# 10       6.783270e+09      0.017871
# 11       6.788530e+09      0.012153
# 12       6.789936e+09      0.011737
# 13       6.791593e+09      0.011721
# 14       6.793160e+09           NaN
# 15       6.794900e+09           NaN
# 16       6.796767e+09      0.014222
# 17       6.800167e+09      0.011706
# 18       6.801763e+09      0.011545
# 19       6.803268e+09      0.013716
# 20       6.805126e+09      0.013151
# 21       6.806552e+09      0.012480
# 22       6.808772e+09           NaN
# 23       6.818054e+09      0.014387
# 24       6.819768e+09      0.013713
# ...

# %%
IV_files = glob.glob('*ASU*.csv')

total_iv_data = pd.DataFrame({'Channel Freq (Hz)':[],'Rn Al (mOhm)':[],'LO (GHz)':[],'NIST Channel':[]})
for file in IV_files:
    freq_init = file.split('_')[0]
    bias_init = file.split('_')[1]
    freq = freq_init[:-3]
    bias = bias_init[3:-4]
    
    IV_data = pd.read_csv(file,sep=',',index_col=0)
    #print(IV_data)
    new_freq = np.ones(len(IV_data))*float(freq)/1e3
    new_bias_channel = np.ones(len(IV_data))*(float(bias)-1) #shift to NIST numbering for comparision to John's data
    
    IV_data.insert(2,'LO (GHz)',new_freq)
    IV_data.insert(3,'NIST Channel',new_bias_channel)
    #print(IV_data)
    
    total_iv_data = pd.concat([total_iv_data, IV_data])
                             
print(total_iv_data)
total_iv_data.sort_values(by=['Channel Freq (Hz)'],inplace=True)
print(total_iv_data)

total_iv_data.reset_index(inplace=True,drop=True)
print(total_iv_data)
#print(total_iv_data.iloc[5])

drop_indices = np.array([])
for i in np.arange(0,len(total_iv_data['Channel Freq (Hz)'])-1):
    #print(i)
    #print(len(total_iv_data['Channel Freq (Hz)']))
    if np.isnan(total_iv_data['Rn Al (mOhm)'].iat[i]):
        drop_indices = np.append(drop_indices,i)
    """
    if total_iv_data['Channel Freq (Hz)'].iat[i+1] == total_iv_data['Channel Freq (Hz)'].iat[i] \
    and np.isnan(total_iv_data['Rn Al (mOhm)'].iat[i+1]) and ~np.isnan(total_iv_data['Rn Al (mOhm)'].iat[i]):
        drop_indices = np.append(drop_indices, i+1)
    elif total_iv_data['Channel Freq (Hz)'].iat[i+1] == total_iv_data['Channel Freq (Hz)'].iat[i] \
    and ~np.isnan(total_iv_data['Rn Al (mOhm)'].iat[i+1]) and np.isnan(total_iv_data['Rn Al (mOhm)'].iat[i]):
        #print(i)
        drop_indices = np.append(drop_indices, i)
    """ 
total_iv_data.drop(drop_indices,inplace=True)
    
print(total_iv_data)

total_iv_data.to_csv('iv_summary.csv')

#print(total_iv_data.iloc[5])
# Out:
#      Channel Freq (Hz)  Rn Al (mOhm)  LO (GHz)  NIST Channel
# 0         4.044545e+09           NaN      4.25           8.0
# 1         4.049245e+09           NaN      4.25           8.0
# 2         4.051184e+09           NaN      4.25           8.0
# 3         4.053305e+09           NaN      4.25           8.0
# 4         4.055906e+09           NaN      4.25           8.0
# ..                 ...           ...       ...           ...
# 156       4.856118e+09           NaN      4.75          10.0
# 157       4.858346e+09           NaN      4.75          10.0
# 158       4.860538e+09           NaN      4.75          10.0
# 159       4.862738e+09           NaN      4.75          10.0
# 160       4.865224e+09           NaN      4.75          10.0
#
# [2433 rows x 4 columns]
#     Channel Freq (Hz)  Rn Al (mOhm)  LO (GHz)  NIST Channel
# 0        4.044545e+09           NaN      4.25           9.0
# 0        4.044545e+09           NaN      4.25          10.0
# ...

# %%
# %matplotlib qt
plt.figure(figsize=(10,6))

bias_data = pd.read_csv('iv_summary.csv',sep=',')
plt.plot(bias_data['Channel Freq (Hz)']/1e9,bias_data['NIST Channel'],'.',label='Receiver Measurement',alpha=1)

john_is_dark_pixel = np.load('AliCPT_first_detector_module_design_mapping/is_dark_pixel.npy')
print(john_is_dark_pixel)


john_data_design_freq = np.load('AliCPT_first_detector_module_design_mapping/design_frequency.npy')
john_data_bias_line = np.load('AliCPT_first_detector_module_design_mapping/bias_line.npy')
plt.plot(~john_is_dark_pixel*john_data_design_freq/1e9, ~john_is_dark_pixel*john_data_bias_line+0.1,'.',label='Design',alpha=1)
plt.plot(john_is_dark_pixel*john_data_design_freq/1e9, john_is_dark_pixel*john_data_bias_line+0.1,'.',label='Design Dark',alpha=1)

plt.vlines(4.5,5.5,11.5)
plt.vlines(5.0,5.5,11.5)
plt.vlines(5.5,5.5,11.5)
plt.vlines(6.0,5.5,11.5)
plt.vlines(6.5,5.5,11.5)

plt.xlim([3.9,7.1])
plt.ylim([5.5,11.5])
plt.legend(fontsize=20)
plt.xlabel('Frequency (GHz)',fontsize=24)
plt.ylabel('NIST Bias Channel',fontsize=24)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

john_data_bias_line_s = john_data_bias_line[john_data_bias_line >=6]
detector_yield = len(bias_data['NIST Channel'])/len(john_data_bias_line_s)*100
plt.title(f'S Line Yield = {round(detector_yield,1)}%',fontsize=28)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 get_ipython().run_line_magic('matplotlib', 'qt')
# ----> 2 plt.figure(figsize=(10,6))
#       4 bias_data = pd.read_csv('iv_summary.csv',sep=',')
#       5 plt.plot(bias_data['Channel Freq (Hz)']/1e9,bias_data['NIST Channel'],'.',label='Receiver Measurement',alpha=1)
#
# NameError: name 'plt' is not defined

# %%
#increasing data throughput test

tspath = '/home/matt/alicpt_data/time_streams/'

ts_fr,Is_fr,Qs_fr=dm.read_data(tspath+'ts_toneinit_fcenter_6750.0_20240207155941_t_20240207161932.hd5')


# %matplotlib qt
plt.plot(ts_fr-ts_fr[0],Is_fr[1],'.-')

# %%
ivs = []



test_iv = 'toneinit_fcenter_4250.0_20240207130021_t_20240207130454'


total_channel_resp = np.array([])
for iv in ivs:

    result = dm.full_iv_process(iv, f_sawtooth=15, iv_path = '/home/matt/alicpt_data/IV_data', plot=None)

    for ch in range(result['Ites'].shape[0]):
        plt.plot(result['Vtes'][ch], result['Ites'][ch])
    
    total_channel_resp.append(dm.get_channel_response_summary(result))

    
print(total_channel_resp)
total_channel_resp.to_csv('20240207_full_iv_results.csv')
