# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots()

size = 0.3
#vals = np.array([[60., 32.], [37., 40.], [29., 10.]])


vals = np.array([610, 942-610])
labels = f'Optically Active\n{vals[0]} channels; {round(vals[0]/942*100,1)}%', f'No Optical Response\n{vals[1]} channels; {round(vals[1]/942*100,1)}%'


cmap = plt.colormaps["tab20c"]
outer_colors = cmap(np.arange(3)*4)
#inner_colors = cmap([1, 2, 5, 6, 9, 10])

ax.pie(vals, radius=1, colors=outer_colors, labels = labels,
       wedgeprops=dict(width=size, edgecolor='w'))

#ax.pie(vals2, radius=1-size, colors=inner_colors,
#       wedgeprops=dict(width=size, edgecolor='w'))

ax.set(aspect="equal", title='Preliminary Detector Statistics for South Network')
#fig.legend(bbox_to_anchor = [0.5, 0.2])
fig.savefig('./asc_plots/module_statistics.png',dpi=150)

plt.show()
