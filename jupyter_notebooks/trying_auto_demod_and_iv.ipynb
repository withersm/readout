# %%
import matplotlib.pyplot as plt
import sys
sys.path.append('/home/matt/readout/host')
import ali_offline_demod as dm
import imp
imp.reload(dm)
# Out:
# /tmp/ipykernel_781149/3979263354.py:5: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   import imp
# <module 'ali_offline_demod' from '/home/matt/readout/host/ali_offline_demod.py'>

# %%
test_ts_1 = 'ts_toneinit_fcenter_4250.0_20240202104043_t_20240202122806.hd5'
test_ts_2 = 'ts_toneinit_fcenter_4250.0_20240202151540_t_20240202174221.hd5'

#result_1 = dm.full_demod_process(test_ts_1, f_sawtooth = 5)
result_2 = dm.full_demod_process(test_ts_2, f_sawtooth = 5)
# Out:
# Delay Region Start (GHz):  4.02
# Delay Region Stop (GHz):  4.03
# bad channel 3
# bad channel 6
# bad channel 12
# bad channel 17
# bad channel 18
# bad channel 19
# bad channel 20
# bad channel 23
# bad channel 26
# bad channel 38
# bad channel 45
# bad channel 52
# bad channel 64
# bad channel 66
# bad channel 75
# bad channel 76
# bad channel 85
# bad channel 96
# bad channel 104
# bad channel 113
# bad channel 114
# bad channel 127
# bad channel 140
# bad channel 143
# bad channel 144
# bad channel 145
# bad channel 151
# bad channel 152
# bad channel 155
# bad channel 159
# bad channel 161
# bad channel 172
# bad channel 173
# bad channel 174
# bad channel 177
# bad channel 178
# bad channel 181
# bad channel 183
# bad channel 185
# bad channel 188
# bad channel 189
# bad channel 194
# bad channel 196
# bad channel 198
# bad channel 201
# bad channel 204
# bad channel 205
# bad channel 210
# bad channel 214
# bad channel 217
# bad channel 222
# bad channel 225
# ...

# %%
print(result_2['channel freqs'].shape)

plt.plot(result_2['demod t'],result_1['demod data'][1],'.')
plt.plot(result_2['demod t'],result_1['demod data'][2],'.')
# Out:
# (233,)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [8], in <cell line: 3>()
#       1 print(result_2['channel freqs'].shape)
# ----> 3 plt.plot(result_2['demod t'],result_1['demod data'][1],'.')
#       4 plt.plot(result_2['demod t'],result_1['demod data'][2],'.')
#
# KeyError: 'demod data'

# %%
test_iv_1 = 'toneinit_fcenter_4250.0_20240202151540_t_20240202155930'
#test_iv_2 = 'toneinit_fcenter_4250.0_20240202151540_t_20240202154218'

result_1 = dm.full_iv_process(test_iv_1,f_sawtooth=5,iv_path = '/home/matt/alicpt_data/IV_data', plot=None)
#result_2 = dm.full_iv_process(test_iv_2,f_sawtooth=5)
# Out:
# /home/matt/readout/host/ali_offline_demod.py:506: RuntimeWarning: divide by zero encountered in log10
#   mag = 20* np.log10(np.abs(sweep_Z))
# /home/matt/.local/readout/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Delay Region Start (GHz):  4.02
# Delay Region Stop (GHz):  4.03
# 3.372806407385219
# /home/matt/.local/readout/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/matt/.local/readout/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# (233, 188)

# %%
print(result_1['Rtes'].shape)
# Out:
# (233, 188)
