# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys
sys.path.append('../host/')

from ali_offline_demod import *
from scipy.signal import find_peaks
from scipy.fft import fft, fftfreq, fftshift, rfft




from tabulate import tabulate

# %%
# !conda install conda-forge::prettytable

# %%
#measure the squid curve freq

mag_0 = np.abs(I[0]+1j*Q[0])
mag_0_zeroed = mag_0 - np.average(mag_0)
t_corr = np.linspace(0,10,len(t))

fig, ax = plt.subplots(1)

ax.plot(t_corr, mag_0_zeroed)
ax.set_xlim([0,None])

peaks = find_peaks(mag_0_zeroed,height=0, threshold=None)
print(peaks[0])
ax.plot(t_corr[peaks[0]],mag_0_zeroed[peaks[0]],'.')

diff = np.diff(peaks[0])
print(diff)

fig_2,ax_2 = plt.subplots(1)

ax_2.hist(diff)
diff_avg = np.average(diff)

ax_2.vlines(diff_avg,0,40,color='tab:orange',linestyle='--')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 #measure the squid curve freq
# ----> 3 mag_0 = np.abs(I[0]+1j*Q[0])
#       4 mag_0_zeroed = mag_0 - np.average(mag_0)
#       5 t_corr = np.linspace(0,10,len(t))
#
# NameError: name 'I' is not defined

# %%
#moving to ~3 Phi0

t, I, Q = read_data('../data/time_streams/ts_toneinit_fcenter_5050.0_20250131142045_t_20250131150935.hd5')


fig, ax = plt.subplots(1)
for i in [10]:#range(len(I)): #channel 10 is a nice one
    #ax.plot(t,I[0])
    #ax.plot(t,Q[0])
    mag = np.abs(I[i]+1j*Q[i])
    ax.plot(np.linspace(0,10,len(t)),mag + i*np.average(mag))

# %%
mag_0 = np.abs(I[10]+1j*Q[10])
mag_0_zeroed = mag_0 - np.average(mag_0)
t_corr = np.linspace(0,10,len(t))

fig, ax = plt.subplots(1)

ax.plot(t_corr, mag_0_zeroed)
ax.set_xlim([0,None])

peaks = find_peaks(mag_0_zeroed,height=0, threshold=None)
print(peaks[0])
ax.plot(t_corr[peaks[0]],mag_0_zeroed[peaks[0]],'.')

diff = np.diff(peaks[0])
print(diff)

fig_2,ax_2 = plt.subplots(1)

ax_2.hist(diff)
diff_avg = np.average(diff)

ax_2.vlines(diff_avg,0,40,color='tab:orange',linestyle='--')
# Out:
# [  13   44   76  108  138  169  197  230  262  294  326  358  389  422
#   453  485  516  548  581  612  644  676  708  738  771  803  835  865
#   896  928  959  991 1022 1055 1087 1117 1149 1180 1212 1244 1277 1309
#  1341 1372 1402 1434 1466 1497 1528 1559 1590 1622 1655 1684 1714 1745
#  1777 1809 1842 1872 1904 1936 1967 1999 2030 2063 2095 2126 2156 2186
#  2215 2246 2278 2310 2343 2373 2405 2436 2469 2499 2530 2560 2591 2624
#  2655 2688 2718 2751 2783 2811 2842 2874 2907 2937 2970 3002 3035 3066
#  3098 3129 3162 3194 3226 3257 3289 3320 3350 3382 3412 3445 3478 3509
#  3542 3573 3604 3635 3668 3699 3732 3762 3794 3825 3856 3889 3921 3953
#  3984 4015 4045 4073 4106 4138 4170 4199 4231 4262 4294 4326 4357 4389
#  4421 4453 4485 4518 4548 4580 4612 4645 4675 4707 4738 4769 4800 4828
#  4861]
# [31 32 32 30 31 28 33 32 32 32 32 31 33 31 32 31 32 33 31 32 32 32 30 33
#  32 32 30 31 32 31 32 31 33 32 30 32 31 32 32 33 32 32 31 30 32 32 31 31
# ...

# %%
# going to 4 Phi0

t, I, Q = read_data('../data/time_streams/ts_toneinit_fcenter_5050.0_20250131142045_t_20250131151838.hd5')

print(f'Num Channels = {len(I)}')


fig, ax = plt.subplots(1)
for i in [15]:#range(len(I)):
    #ax.plot(t,I[0])
    #ax.plot(t,Q[0])
    mag = np.abs(I[i]+1j*Q[i])
    ax.plot(np.linspace(0,10,len(t)),mag + i*np.average(mag))
# Out:
# Num Channels = 1002

# %%
mag_0 = np.abs(I[0]+1j*Q[0])
mag_0_zeroed = mag_0 - np.average(mag_0)
t_corr = np.linspace(0,10,len(t))

fig, ax = plt.subplots(1)

ax.plot(t_corr, mag_0_zeroed)
ax.set_xlim([0,None])

peaks = find_peaks(mag_0_zeroed,height=0, threshold=None)
print(peaks[0])
ax.plot(t_corr[peaks[0]],mag_0_zeroed[peaks[0]],'.')

diff = np.diff(peaks[0])
print(diff)

fig_2,ax_2 = plt.subplots(1)

ax_2.hist(diff)
diff_avg = np.average(diff)

ax_2.vlines(diff_avg,0,40,color='tab:orange',linestyle='--')
# Out:
# [  21   53   85  117  147  177  210  241  274  306  339  369  401  433
#   464  495  526  559  591  624  656  687  719  751  784  816  848  880
#   910  942  974 1005 1037 1069 1101 1134 1164 1196 1228 1261 1293 1324
#  1357 1388 1419 1450 1482 1512 1543 1575 1606 1637 1670 1702 1733 1766
#  1797 1829 1860 1893 1925 1957 1989 2020 2053 2084 2117 2148 2181 2212
#  2244 2276 2307 2339 2371 2402 2433 2464 2496 2528 2558 2587 2619 2649
#  2679 2711 2744 2774 2807 2836 2868 2901 2932 2964 2994 3025 3056 3087
#  3115 3147 3179 3209 3241 3272 3305 3335 3367 3397 3428 3460 3491 3523
#  3551 3584 3615 3645 3676 3708 3740 3771 3802 3829 3862 3890 3923 3954
#  3986 4017 4050 4083 4112 4145 4176 4209 4237 4269 4301 4332 4363 4394
#  4425 4456 4488 4519 4551 4581 4612 4643 4676 4708 4738 4770 4801 4833
#  4865]
# [32 32 32 30 30 33 31 33 32 33 30 32 32 31 31 31 33 32 33 32 31 32 32 33
#  32 32 32 30 32 32 31 32 32 32 33 30 32 32 33 32 31 33 31 31 31 32 30 31
# ...

# %%
# going to 3 Phi0; high Z

t, I, Q = read_data('../data/time_streams/ts_toneinit_fcenter_5050.0_20250131142045_t_20250131153110.hd5')

print(f'Num Channels = {len(I)}')


fig, ax = plt.subplots(1)
for i in [6]:#range(len(I)):
    #ax.plot(t,I[0])
    #ax.plot(t,Q[0])
    mag = np.abs(I[i]+1j*Q[i])
    ax.plot(np.linspace(0,10,len(t)),mag + i*np.average(mag))
# Out:
# Num Channels = 1002

# %%
#doubling voltage

t, I, Q = read_data('../data/time_streams/ts_toneinit_fcenter_5050.0_20250131142045_t_20250131153440.hd5')

print(f'Num Channels = {len(I)}')


fig, ax = plt.subplots(1)
for i in [6]:#range(len(I)):
    #ax.plot(t,I[0])
    #ax.plot(t,Q[0])
    mag = np.abs(I[i]+1j*Q[i])
    ax.plot(np.linspace(0,10,len(t)),mag + i*np.average(mag))

#THIS IS 1 PHI0
# Out:
# Num Channels = 1002

# %%
mag_0 = np.abs(I[10]+1j*Q[10])
mag_0_zeroed = mag_0 - np.average(mag_0)
t_corr = np.linspace(0,10,len(t))

fig, ax = plt.subplots(1)

ax.plot(t_corr, mag_0_zeroed)
ax.set_xlim([0,None])

peaks = find_peaks(mag_0_zeroed,height=0, threshold=None)
print(peaks[0])
ax.plot(t_corr[peaks[0]],mag_0_zeroed[peaks[0]],'.')

diff = np.diff(peaks[0])
print(diff)

fig_2,ax_2 = plt.subplots(1)

ax_2.hist(diff)
diff_avg = np.average(diff)

ax_2.vlines(diff_avg,0,40,color='tab:orange',linestyle='--')
# Out:
# [  26   56   89  121  150  181  212  243  275  306  335  365  395  424
#   453  484  515  542  572  602  631  663  693  723  754  786  816  848
#   876  907  936  967  999 1030 1060 1090 1120 1150 1180 1212 1242 1272
#  1300 1330 1359 1390 1419 1449 1477 1509 1537 1566 1595 1626 1656 1686
#  1716 1746 1778 1811 1842 1873 1904 1936 1965 1996 2024 2053 2085 2114
#  2145 2176 2205 2236 2267 2298 2330 2359 2389 2420 2451 2482 2514 2543
#  2574 2607 2638 2671 2701 2734 2766 2796 2827 2855 2888 2919 2948 2979
#  3009 3042 3073 3106 3135 3168 3199 3231 3262 3288 3317 3349 3380 3410
#  3438 3469 3500 3528 3558 3589 3622 3655 3685 3716 3747 3776 3806 3837
#  3866 3893 3925 3956 3986 4015 4047 4078 4108 4139 4170 4200 4229 4260
#  4292 4321 4350 4381 4406 4437 4467 4497 4529 4560 4592 4621 4648 4678
#  4711 4740 4771 4803 4831 4863]
# [30 33 32 29 31 31 31 32 31 29 30 30 29 29 31 31 27 30 30 29 32 30 30 31
#  32 30 32 28 31 29 31 32 31 30 30 30 30 30 32 30 30 28 30 29 31 29 30 28
# ...

# %%
t, I, Q = read_data('../data/time_streams/ts_toneinit_fcenter_5050.0_20250131142045_t_20250131153721.hd5')

print(f'Num Channels = {len(I)}')


fig, ax = plt.subplots(1)
for i in [6]:#range(len(I)):
    #ax.plot(t,I[0])
    #ax.plot(t,Q[0])
    mag = np.abs(I[i]+1j*Q[i])
    ax.plot(np.linspace(0,10,len(t)),mag + i*np.average(mag))
# Out:
# Num Channels = 1002

# %%
mag_0 = np.abs(I[10]+1j*Q[10])
mag_0_zeroed = mag_0 - np.average(mag_0)
t_corr = np.linspace(0,10,len(t))

fig, ax = plt.subplots(1)

ax.plot(t_corr, mag_0_zeroed)
ax.set_xlim([0,None])

peaks = find_peaks(mag_0_zeroed,height=0, threshold=None)
print(peaks[0])
ax.plot(t_corr[peaks[0]],mag_0_zeroed[peaks[0]],'.')

diff = np.diff(peaks[0])
print(diff)

fig_2,ax_2 = plt.subplots(1)

ax_2.hist(diff)
diff_avg = np.average(diff)

ax_2.vlines(diff_avg,0,40,color='tab:orange',linestyle='--')
# Out:
# [   7   24   40   55   72   87  103  119  133  149  164  180  197  212
#   228  244  260  276  290  307  323  339  356  372  388  404  420  434
#   450  466  482  497  512  528  545  560  576  593  608  623  640  656
#   672  688  705  721  737  753  770  786  801  817  834  850  865  879
#   895  910  924  941  957  973  990 1006 1022 1037 1053 1069 1084 1100
#  1117 1132 1148 1164 1180 1195 1210 1227 1243 1259 1276 1291 1307 1323
#  1340 1356 1372 1388 1405 1421 1437 1453 1469 1485 1501 1517 1533 1549
#  1566 1582 1598 1613 1629 1645 1660 1676 1693 1709 1725 1741 1757 1773
#  1789 1805 1822 1837 1854 1870 1886 1902 1918 1933 1949 1965 1982 1998
#  2013 2029 2046 2062 2078 2094 2110 2125 2141 2158 2174 2188 2205 2220
#  2235 2250 2266 2281 2297 2313 2330 2346 2362 2377 2394 2407 2423 2440
#  2456 2470 2487 2502 2518 2532 2548 2563 2578 2593 2610 2624 2639 2655
#  2672 2688 2704 2720 2737 2753 2770 2786 2802 2818 2835 2851 2867 2883
# ...

# %%
t, I, Q = read_data('../data/time_streams/ts_toneinit_fcenter_5050.0_20250131142045_t_20250131154014.hd5')

print(f'Num Channels = {len(I)}')


fig, ax = plt.subplots(1)
for i in [30]:#range(len(I)): #ch 6 is a good one
    #ax.plot(t,I[0])
    #ax.plot(t,Q[0])
    mag = np.abs(I[i]+1j*Q[i])
    ax.plot(np.linspace(0,10,len(t)),mag) #- i*np.average(mag))
    ax.plot(np.linspace(0,10,len(t)),I[i])
    ax.plot(np.linspace(0,10,len(t)),Q[i])
# Out:
# Num Channels = 1002

# %%
# %matplotlib qt
mag_0 = np.abs(I[10]+1j*Q[10])
mag_0_zeroed = mag_0 - np.average(mag_0)
t_corr = np.linspace(0,10,len(t))

fig, ax = plt.subplots(1)

ax.plot(t_corr, mag_0_zeroed)
ax.set_xlim([0,None])

peaks = find_peaks(mag_0_zeroed,height=0, threshold=None)
print(peaks[0])
ax.plot(t_corr[peaks[0]],mag_0_zeroed[peaks[0]],'.')

diff = np.diff(peaks[0])
print(diff)

fig_2,ax_2 = plt.subplots(1)

ax_2.hist(diff)
diff_avg = np.average(diff)

ax_2.vlines(diff_avg,0,40,color='tab:orange',linestyle='--')
# Out:
# [   9   20   31   41   53   63   74   85   95  105  116  126  137  146
#   157  167  178  187  197  208  218  229  240  251  261  272  283  294
#   305  316  326  338  348  358  369  379  389  401  408  418  428  438
#   449  460  469  480  491  502  513  524  535  545  556  567  578  589
#   600  609  620  631  642  653  664  674  686  696  706  716  726  736
#   747  756  766  777  788  798  808  818  829  840  851  861  872  883
#   893  903  913  924  935  946  956  967  976  986  997 1008 1018 1029
#  1037 1047 1058 1068 1078 1089 1099 1110 1121 1132 1143 1154 1164 1174
#  1185 1196 1207 1218 1229 1239 1251 1261 1272 1282 1292 1302 1313 1323
#  1334 1345 1356 1367 1378 1388 1399 1409 1419 1429 1440 1451 1461 1472
#  1483 1494 1505 1516 1526 1537 1547 1557 1568 1579 1589 1601 1611 1622
#  1633 1643 1653 1664 1674 1685 1695 1705 1716 1727 1737 1748 1759 1770
#  1781 1792 1802 1811 1822 1833 1843 1854 1865 1874 1886 1896 1907 1918
# ...

# %%
fig, ax = plt.subplots(1)

i = 10 #channel

ax.plot(I[i],Q[i],'.-')


deltaQ = Q[i] - np.mean(Q[i])
deltaI = I[i] - np.mean(I[i])

alpha = np.mean(deltaQ * deltaI) / np.mean(deltaI * deltaI)

theta = np.arctan(alpha)

print(theta)

if theta > 0:
    print('>')
    rotated = (I[i] + 1j*Q[i]) * np.exp(-1j*(theta - np.pi/4))
elif theta < 0:
    print('<')
    rotated = (I[i] + 1j*Q[i]) * np.exp(-1j*(theta + np.pi/4))
else:
    rotated = (I[i] + 1j*Q[i])

ax.plot(np.real(rotated), np.imag(rotated), alpha = 0.5)
# Out:
# 0.9525752149689581
# >

# %%
t, I, Q = read_data('../data/time_streams/ts_toneinit_fcenter_5050.0_20250201125701_t_20250201141648.hd5')

def get_theta(I,Q):
    deltaQ = Q - np.mean(Q)
    deltaI = I - np.mean(I)
    
    alpha = np.mean(deltaQ * deltaI) / np.mean(deltaI * deltaI)
    
    theta = np.arctan(alpha)
    
    #print(theta)

    """
    
    if theta > 0:
        #print('>')
        rotated = (I + 1j*Q) * np.exp(-1j*(theta - np.pi/4))
    elif theta < 0:
        #print('<')
        rotated = (I + 1j*Q) * np.exp(-1j*(theta + np.pi/4))
    else:
        rotated = (I + 1j*Q)

    """

    return theta, alpha



theta_array = np.array([])
alpha_array = np.array([])
for i in range(len(I)):
    theta, alpha = get_theta(I[i], Q[i])
    #print(theta)
    theta_array = np.append(theta_array, theta)
    alpha_array = np.append(alpha_array, alpha)
"""...
import pandas as pd
a = pd.DataFrame(theta_array)
# index = np.arange(theta_array.shape[0])
# ta = np.array([index,theta_array])
print(a)
print(alpha_array)
"""

#now rotate with the thetas
#print(len(theta_array))
#print(np.shape((I[i])))

#print(theta_array)
#print(alpha_array)


rotated_array = np.empty(np.shape(I[0]))

for i in range(len(theta_array)):
    if theta_array[i] > 0:
        #print('>')
        if alpha_array[i] > 0:
            rotated = (I[i] + 1j*Q[i]) * np.exp(-1j*(theta_array[i] + np.pi/4))
        else:
            rotated = (I[i] + 1j*Q[i]) * np.exp(-1j*(theta_array[i] + np.pi/4 + np.pi/2))
    elif theta_array[i] < 0:
        #print('<')
        if alpha_array[i] > 0:
            rotated = (I[i] + 1j*Q[i]) * np.exp(-1j*(theta_array[i] - np.pi/4))
        else:
            rotated = (I[i] + 1j*Q[i]) * np.exp(-1j*(theta_array[i] - np.pi/4 + np.pi/2))
    else:
        rotated = (I[i] + 1j*Q[i])

    rotated_array = np.vstack([rotated_array, rotated])

#print(rotated_array)

I_rotated = np.real(rotated_array)
Q_rotated = np.imag(rotated_array)

theta_2_array = np.array([])
alpha_2_array = np.array([])
for i in range(len(I)):
    theta, alpha = get_theta(I_rotated[i], Q_rotated[i])
    #print(theta)
    theta_2_array = np.append(theta_2_array, theta)
    alpha_2_array = np.append(alpha_2_array, alpha)


rotated_2_array = np.empty(np.shape(I[0]))

for i in range(len(theta_array)):
    if theta_2_array[i] > 0:
        #print('>')
        if alpha_2_array[i] > 0:
            rotated = (I_rotated[i] + ts_toneinit_fcenter_5050.0_20250201125701_t_202502011416481j*Q_rotated[i]) * np.exp(-1j*(theta_2_array[i] + np.pi/4))
        else:
            rotated = (I_rotated[i] + 1j*Q_rotated[i]) * np.exp(-1j*(theta_2_array[i] + np.pi/4 + np.pi/2))
    elif theta_2_array[i] < 0:
        #print('<')
        if alpha_2_array[i] > 0:
            rotated = (I_rotated[i] + 1j*Q_rotated[i]) * np.exp(-1j*(theta_2_array[i] - np.pi/4))
        else:
            rotated = (I_rotated[i] + 1j*Q_rotated[i]) * np.exp(-1j*(theta_2_array[i] - np.pi/4 + np.pi/2))
    else:
        rotated = (I_rotated[i] + 1j*Q_rotated[i])

    rotated_2_array = np.vstack([rotated_2_array, rotated])

I_rotated_2 = np.real(rotated_2_array)
Q_rotated_2 = np.imag(rotated_2_array)


ch = 10
fig, ax = plt.subplots(1)
ax.plot(I[ch],Q[ch])
ax.plot(I_rotated[ch],Q_rotated[ch])
ax.plot(I_rotated_2[ch],Q_rotated_2[ch])
ax.axis('equal')

#test
theta_return, alpha_return = get_theta(I_rotated[ch], Q_rotated[ch])
theta_return_2, alpha_return_2 = get_theta(I_rotated_2[ch], Q_rotated_2[ch])
print(theta_array[ch]/np.pi, alpha_array[ch])
print(theta_return/np.pi,alpha_return)
print(theta_return_2/np.pi,alpha_return_2)

#did this with data above, then our attempt with external flux ramp
# Out:
# /tmp/ipykernel_873831/986907165.py:7: RuntimeWarning: invalid value encountered in scalar divide
#   alpha = np.mean(deltaQ * deltaI) / np.mean(deltaI * deltaI)
# 0.1575741509957121 0.53987153363762
# -0.22737438467795834 -0.8670642434458526
# -0.2479875629268134 -0.9874347582291799

# %%
ch = 21
fig, ax = plt.subplots(1)
ax.plot(I[ch],Q[ch])
ax.plot(I_rotated[ch],Q_rotated[ch])
ax.plot(I_rotated_2[ch],Q_rotated_2[ch])
ax.axis('equal')

fig_2, ax_2 = plt.subplots(1)
ax_2.plot(np.linspace(0,10,len(I[ch])),I_rotated_2[ch])
ax_2.plot(np.linspace(0,10,len(I[ch])),Q_rotated_2[ch])
ax_2.plot(np.linspace(0,10,len(I[ch])),np.abs(I_rotated_2[ch]+1j*Q_rotated_2[ch]))

#test
theta_return, alpha_return = get_theta(I_rotated[ch], Q_rotated[ch])
theta_return_2, alpha_return_2 = get_theta(I_rotated_2[ch], Q_rotated_2[ch])
print(theta_array[ch]/np.pi, alpha_array[ch])
print(theta_return/np.pi,alpha_return)
print(theta_return_2/np.pi,alpha_return_2)


#make a bunch of these plots
# Out:
# -0.08602750771206162 -0.2770417168738561
# -0.2468610474297341 -0.9804693440962888
# -0.24934225279502792 -0.9958757687591877

# %%
print(theta_2_array

# %%
t, I, Q = read_data('../data/time_streams/ts_toneinit_fcenter_5050.0_20250201125701_t_20250201133659.hd5')

def get_theta(I,Q):
    deltaQ = Q - np.mean(Q)
    deltaI = I - np.mean(I)
    
    alpha = np.mean(deltaQ * deltaI) / np.mean(deltaI * deltaI)
    
    theta = np.arctan(alpha)
    
    #print(theta)

    """
    
    if theta > 0:
        #print('>')
        rotated = (I + 1j*Q) * np.exp(-1j*(theta - np.pi/4))
    elif theta < 0:
        #print('<')
        rotated = (I + 1j*Q) * np.exp(-1j*(theta + np.pi/4))
    else:
        rotated = (I + 1j*Q)

    """

    return theta, alpha



theta_array = np.array([])
alpha_array = np.array([])
for i in range(len(I)):
    theta, alpha = get_theta(I[i], Q[i])
    #print(theta)
    theta_array = np.append(theta_array, theta)
    alpha_array = np.append(alpha_array, alpha)
"""...
import pandas as pd
a = pd.DataFrame(theta_array)
# index = np.arange(theta_array.shape[0])
# ta = np.array([index,theta_array])
print(a)
print(alpha_array)
"""

#now rotate with the thetas
#print(len(theta_array))
#print(np.shape((I[i])))

#print(theta_array)
#print(alpha_array)


rotated_array = np.empty(np.shape(I[0]))

for i in range(len(theta_array)):
    if theta_array[i] > 0:
        #print('>')
        if alpha_array[i] > 0:
            rotated = (I[i] + 1j*Q[i]) * np.exp(-1j*(theta_array[i] + np.pi/4))
        else:
            rotated = (I[i] + 1j*Q[i]) * np.exp(-1j*(theta_array[i] + np.pi/4 + np.pi/2))
    elif theta_array[i] < 0:
        #print('<')
        if alpha_array[i] > 0:
            rotated = (I[i] + 1j*Q[i]) * np.exp(-1j*(theta_array[i] - np.pi/4))
        else:
            rotated = (I[i] + 1j*Q[i]) * np.exp(-1j*(theta_array[i] - np.pi/4 + np.pi/2))
    else:
        rotated = (I[i] + 1j*Q[i])

    rotated_array = np.vstack([rotated_array, rotated])
# Out:
# /tmp/ipykernel_873831/865378871.py:7: RuntimeWarning: invalid value encountered in scalar divide
#   alpha = np.mean(deltaQ * deltaI) / np.mean(deltaI * deltaI)

# %%
ch = 21
fig, ax = plt.subplots(1)
ax.plot(I[ch],Q[ch])
ax.plot(I_rotated[ch],Q_rotated[ch])
ax.plot(I_rotated_2[ch],Q_rotated_2[ch])
ax.axis('equal')

#test
theta_return, alpha_return = get_theta(I_rotated[ch], Q_rotated[ch])
theta_return_2, alpha_return_2 = get_theta(I_rotated_2[ch], Q_rotated_2[ch])
print(theta_array[ch]/np.pi, alpha_array[ch])
print(theta_return/np.pi,alpha_return)
print(theta_return_2/np.pi,alpha_return_2)


#make a bunch of these plots
# Out:
# -0.08862193501504448 -0.28583798633237106
# -0.24594883553161434 -0.9748643301659626
# -0.24917320482205016 -0.9948185396363247

# %%
ch = 21

fig, ax = plt.subplots(1)

#ax.plot(np.linspace(0,10,len(I_rotated[ch])),np.abs(I_rotated[ch]+1j*Q_rotated[ch]))
ax.plot(np.linspace(0,10,len(I_rotated_2[ch])),I_rotated_2[ch])

# %%
ts_toneinit_fcenter_5050.0_20250201125701_t_20250201133659

# %%
rotval_array = np.empty(np.shape(theta_2_array[i]))

for i in range(len(theta_array)):
    if theta_2_array[i] > 0:
        #print('>')
        if alpha_2_array[i] > 0:
            rotval = np.exp(-1j*(theta_array[i] + theta_2_array[i] + np.pi/4))
        else:
            rotval = np.exp(-1j*(theta_array[i] + theta_2_array[i] + np.pi/4 + np.pi/2))
    elif theta_2_array[i] < 0:
        #print('<')
        if alpha_2_array[i] > 0:
            rotval = np.exp(-1j*(theta_array[i] + theta_2_array[i] - np.pi/4))
        else:
            rotval = np.exp(-1j*(theta_array[i] + theta_2_array[i] - np.pi/4 + np.pi/2))
    else:
        rotval = 1

    rotval_array = np.vstack([rotval_array, rotval])

# %%
rotval_array
# Out:
# array([[0.        +0.j        ],
#        [1.        +0.j        ],
#        [0.99477607+0.10208118j],
#        ...,
#        [1.        +0.j        ],
#        [1.        +0.j        ],
#        [1.        +0.j        ]], shape=(1003, 1))

# %% [markdown]
# ## Begin work at home

# %%
# %matplotlib qt

# %%
t, I, Q = read_data('../../../temp_data/data_at_asu/time_streams/ts_toneinit_fcenter_5050.0_20250203135136_t_20250203135754.hd5')#ts_toneinit_fcenter_5050.0_20250201125701_t_20250201141648.hd5')


def get_theta(I,Q):
    deltaQ = Q - np.mean(Q)
    deltaI = I - np.mean(I)
    
    alpha = np.mean(deltaQ * deltaI) / np.mean(deltaI * deltaI)
    
    theta = np.arctan(alpha)
    
    #print(theta)

    """
    
    if theta > 0:
        #print('>')
        rotated = (I + 1j*Q) * np.exp(-1j*(theta - np.pi/4))
    elif theta < 0:
        #print('<')
        rotated = (I + 1j*Q) * np.exp(-1j*(theta + np.pi/4))
    else:
        rotated = (I + 1j*Q)

    """

    return theta, alpha



theta_array = np.array([])
alpha_array = np.array([])
for i in range(len(I)):
    theta, alpha = get_theta(I[i], Q[i])
    #print(theta)
    theta_array = np.append(theta_array, theta)
    alpha_array = np.append(alpha_array, alpha)
"""...
import pandas as pd
a = pd.DataFrame(theta_array)
# index = np.arange(theta_array.shape[0])
# ta = np.array([index,theta_array])
print(a)
print(alpha_array)
"""

#now rotate with the thetas
#print(len(theta_array))
#print(np.shape((I[i])))

#print(theta_array)
#print(alpha_array)


rotated_array = np.empty(np.shape(I[0]))

for i in range(len(theta_array)):
    if theta_array[i] > 0:
        #print('>')
        if alpha_array[i] > 0:
            rotated = (I[i] + 1j*Q[i]) * np.exp(-1j*(theta_array[i] + np.pi/4))
        else:
            rotated = (I[i] + 1j*Q[i]) * np.exp(-1j*(theta_array[i] + np.pi/4 + np.pi/2))
    elif theta_array[i] < 0:
        #print('<')
        if alpha_array[i] > 0:
            rotated = (I[i] + 1j*Q[i]) * np.exp(-1j*(theta_array[i] - np.pi/4))
        else:
            rotated = (I[i] + 1j*Q[i]) * np.exp(-1j*(theta_array[i] - np.pi/4 + np.pi/2))
    else:
        rotated = (I[i] + 1j*Q[i])

    rotated_array = np.vstack([rotated_array, rotated])

#print(rotated_array)

I_rotated = np.real(rotated_array)
Q_rotated = np.imag(rotated_array)

theta_2_array = np.array([])
alpha_2_array = np.array([])
for i in range(len(I)):
    theta, alpha = get_theta(I_rotated[i], Q_rotated[i])
    #print(theta)
    theta_2_array = np.append(theta_2_array, theta)
    alpha_2_array = np.append(alpha_2_array, alpha)


rotated_2_array = np.empty(np.shape(I[0]))

for i in range(len(theta_array)):
    if theta_2_array[i] > 0:
        #print('>')
        if alpha_2_array[i] > 0:
            rotated = (I_rotated[i] + 1j*Q_rotated[i]) * np.exp(-1j*(theta_2_array[i] + np.pi/4))
        else:
            rotated = (I_rotated[i] + 1j*Q_rotated[i]) * np.exp(-1j*(theta_2_array[i] + np.pi/4 + np.pi/2))
    elif theta_2_array[i] < 0:
        #print('<')
        if alpha_2_array[i] > 0:
            rotated = (I_rotated[i] + 1j*Q_rotated[i]) * np.exp(-1j*(theta_2_array[i] - np.pi/4))
        else:
            rotated = (I_rotated[i] + 1j*Q_rotated[i]) * np.exp(-1j*(theta_2_array[i] - np.pi/4 + np.pi/2))
    else:
        rotated = (I_rotated[i] + 1j*Q_rotated[i])

    rotated_2_array = np.vstack([rotated_2_array, rotated])

I_rotated_2 = np.real(rotated_2_array)
Q_rotated_2 = np.imag(rotated_2_array)


ch = 10
fig, ax = plt.subplots(1)
ax.plot(I[ch],Q[ch])
ax.plot(I_rotated[ch],Q_rotated[ch])
ax.plot(I_rotated_2[ch],Q_rotated_2[ch])
ax.axis('equal')

#test
theta_return, alpha_return = get_theta(I_rotated[ch], Q_rotated[ch])
theta_return_2, alpha_return_2 = get_theta(I_rotated_2[ch], Q_rotated_2[ch])
print(theta_array[ch]/np.pi, alpha_array[ch])
print(theta_return/np.pi,alpha_return)
print(theta_return_2/np.pi,alpha_return_2)

#did this with data above, then our attempt with external flux ramp
# Out:
# C:\Users\mowit\AppData\Local\Temp\ipykernel_29048\657057301.py:8: RuntimeWarning: invalid value encountered in scalar divide
#   alpha = np.mean(deltaQ * deltaI) / np.mean(deltaI * deltaI)
# -0.06318280748156434 -0.2011432991027809
# -0.22592768205320352 -0.8591335958190642
# -0.2703057173043967 -1.1364758710658154

# %%
#I/Q Adjust LUT

lut_iq_adjust = np.exp(1j*theta_array)

print(lut_iq_adjust)


fig_check, ax_check = plt.subplots(1)

ax_check.plot(np.real(lut_iq_adjust), np.imag(lut_iq_adjust))
# Out:
# [0.50463169-0.86333473j 0.84959405+0.52743715j 0.3963987 +0.91807847j ...
#         nan       +nanj        nan       +nanj        nan       +nanj]

# %%
ch = 37
num_packets = 32

fig, ax = plt.subplots(1)

t = np.linspace(0,10,len(I_rotated_2[ch])) # fix time stamping issue
mag = np.abs(I_rotated_2 + 1j*Q_rotated_2)

#ax.plot(np.linspace(0,10,len(I_rotated[ch])),np.abs(I_rotated[ch]+1j*Q_rotated[ch]))
ax.plot(t,mag[ch],'.-')
ax.set_title(f'I/Q Rotated Data; Ch = {ch}')

idx_start = 14 #find_start_idx_internal_fr(t, mag[ch], 32)

print(f'idx_start = {idx_start}')

#set to start
t_correct_start = t[idx_start:]
I_correct_start = I_rotated_2[:,idx_start:]
Q_correct_start = Q_rotated_2[:,idx_start:]

print(np.shape(I_correct_start))
print(np.shape(I_rotated_2))

mag_correct_start = np.abs(I_correct_start + 1j*Q_correct_start)

fig_2, ax_2 = plt.subplots(1)
ax_2.plot(t_correct_start, mag_correct_start[ch],'.-')
ax_2.set_title(f'Setting Start to Beginning of First Full FR; Ch = {ch}')

#fix length so that data stream is an integer multiple of the number of packets (i.e., 32 for this test)
int_len = int(len(t_correct_start) / num_packets) * num_packets

#truncate
t_trunc = t_correct_start[:int_len]
I_trunc = I_correct_start[:,:int_len]
Q_trunc = Q_correct_start[:,:int_len]
mag_trunc = np.abs(I_trunc + 1j*Q_trunc)

print(len(t_trunc))
print(np.shape(I_trunc))

print(len(t_trunc)/32)

#stack

t_stack = np.reshape(t_trunc, (int(len(t_trunc)/num_packets),num_packets))
I_stack = np.reshape(I_trunc, (len(I_trunc),int(np.shape(I_trunc)[1]/num_packets),num_packets))
Q_stack = np.reshape(Q_trunc, (len(Q_trunc),int(np.shape(Q_trunc)[1]/num_packets),num_packets))
Z_stack = I_stack + 1j*Q_stack
mag_stack = np.abs(I_stack + 1j*Q_stack)
"""
t_stack = np.empty((int(len(t_trunc)/num_packets),num_packets))
I_stack = np.empty((len(I_trunc),int(np.shape(I_trunc)[1]/num_packets),num_packets))
Q_stack = np.empty((len(Q_trunc),int(np.shape(Q_trunc)[1]/num_packets),num_packets))

for i in range(int(np.shape(I_trunc)[1]/num_packets)):
    if i == 0:
        t_stack[i] = t_trunc[0:num_packets]
    else:
        t_stack[i] = t_trunc[i*num_packets-1:(i+1)*num_packets-1]

for i in range(int(np.shape(I_trunc)[1]/num_packets)):
    if i == 0:
        I_stack[:,i,:] = I_trunc[:,0:num_packets]
    else:
        I_stack[:,i,:] = I_trunc[:,i*num_packets-2:(i+1)*num_packets-2]

for i in range(int(np.shape(Q_trunc)[1]/num_packets)):
    if i == 0:
        Q_stack[:,i,:] = Q_trunc[:,0:num_packets]
    else:
        Q_stack[:,i,:] = Q_trunc[:,i*num_packets-2:(i+1)*num_packets-2]

mag_stack = np.abs(I_stack + 1j*Q_stack)
"""

#for I and Q [ch][chunk][value]


fig_3, ax_3 = plt.subplots(1)

for i in range(np.shape(t_stack)[0]):
    #ax_3.plot(t_trunc, mag_trunc[ch])
    ax_3.plot(t_stack[i]*len(I_rotated_2[ch])/10,mag_stack[ch][i],'.-') #t_stack[i],
ax_3.set_title(f'Breaking into FR Chunks; Ch = {ch}')


fig_4, ax_4 = plt.subplots(1)

for i in range(np.shape(t_stack)[0]):
    ax_4.plot(t_stack[0], mag_stack[ch][i])
ax_4.set_title(f'Stacking FR Chunks; Ch = {ch}')

#average stacks
I_averaged_stacks = np.mean(I_stack, axis=1)
Q_averaged_stacks = np.mean(Q_stack, axis=1)
Z_averaged_stacks = I_averaged_stacks +1j*Q_averaged_stacks
mag_averaged_stacks = np.abs(Z_averaged_stacks)


print(np.shape(I_averaged_stacks))

fig_5, ax_5 = plt.subplots(1)
ax_5.plot(t_stack[0],mag_averaged_stacks[ch],label='Original')
ax_5.plot(t_stack[0],mag_averaged_stacks[ch]-np.average(mag_averaged_stacks[ch]),label='DC Removed')
ax_5.set_title(f'Averaging Stack; Ch = {ch}')
ax_5.legend()


zero_padding = np.zeros(np.shape(I_averaged_stacks))

I_averaged_stacks_padded = np.hstack([I_averaged_stacks, zero_padding])
Q_averaged_stacks_padded = np.hstack([Q_averaged_stacks, zero_padding])
Z_averaged_stacks_padded = I_averaged_stacks_padded +1j*Q_averaged_stacks_padded

#take fft
fourier_transform = fft(Z_averaged_stacks-np.mean(Z_averaged_stacks,axis=1)[:, np.newaxis])
print(fourier_transform)

N = len(Z_averaged_stacks[0])
T = np.average(np.diff(t_stack[0]))
freqs = fftfreq(N, T)

fig_6, ax_6 = plt.subplots(1)
ax_6.stem(freqs,np.abs(fourier_transform[ch]))
ax_6.set_title(f'FFT; Ch = {ch}')

#build LUT

t_LUT = np.arange(0,32,1) #np.linspace(0, np.average(np.diff(t_stack[0])) / 32, 32)#

max_fft_idx = np.argmax(np.abs(fourier_transform),axis=1)
print(max_fft_idx[10])

table_freqs = np.abs(freqs[max_fft_idx]) #makes positive if selecting the negative bin

fig_7, ax_7 = plt.subplots(1)
ax_7.plot(table_freqs,'.')
ax_7.set_title(f'Identified Frequencies; All Chs.')

table_values = np.exp(-1j*(2*np.pi*table_freqs)*t_LUT[:, np.newaxis])  #*(256e6/(2**19-1))
table_values = np.transpose(table_values)

fig_8, ax_8 = plt.subplots(1)

ax_8.plot(np.real(table_values[ch]),np.imag(table_values[ch]))
ax_8.set_aspect('equal', adjustable='box')
ax_8.set_title(f'LUT Values;Ch = {ch}')

fig_9, ax_9 = plt.subplots(1)

ax_9.plot(np.abs(table_values[ch]))
ax_9.set_title(f'LUT Values; Ch = {ch}')

print(table_values[21])

#test



Z_adjusted = np.multiply(Z_stack,table_values[:,np.newaxis,:])
print(np.shape(Z_stack))
print(np.shape(table_values))
print(np.shape(Z_adjusted))



fig_10, ax_10 = plt.subplots(1)
ax_10.plot(t_stack[0],Z_adjusted[ch,0])
ax_10.hlines(np.abs(np.mean(Z_adjusted, axis = 2)[0,0]),t_stack[0,0],t_stack[0,-1],color='tab:orange',linestyle='--',label=f'Average = {np.abs(np.mean(Z_adjusted, axis = 2)[0,0])}')
ax_10.set_title(f'First Corrected Chunk; Ch = {ch}')
ax_10.legend()


Z_averaged_down = np.mean(Z_adjusted, axis = 2)

print(np.shape(Z_averaged_down))






fig_11, ax_11 = plt.subplots(1)

ax_11.plot(Z_averaged_down[ch],'.-')
ax_11.set_title(f'Averaging Every 32 Samples; Ch = {ch}')

"""

I_orig_trunc = I[:,idx_start:]
Q_orig_trunc = Q[:,idx_start:]

I_orig_trunc = I_orig_trunc[:,:int_len]
Q_orig_trunc = I_orig_trunc[:,:int_len]


I_orig_stack = np.reshape(I_orig_trunc, (len(I_orig_trunc),int(np.shape(I_orig_trunc)[1]/num_packets),num_packets))
Q_orig_stack = np.reshape(Q_orig_trunc, (len(Q_orig_trunc),int(np.shape(Q_orig_trunc)[1]/num_packets),num_packets))
Z_orig_stack = I_orig_stack + 1j*Q_orig_stack
mag_orig_stack = np.abs(I_orig_stack + 1j*Q_orig_stack)

Z_orig_adjusted = np.multiply(Z_orig_stack,table_values[:,np.newaxis,:])



fig_12, ax_12 = plt.subplots(1)
ax_12.plot(t_stack[0],Z_orig_adjusted[ch,0])
ax_12.hlines(np.abs(np.mean(Z_orig_adjusted, axis = 2)[0,0]),t_stack[0,0],t_stack[0,-1],color='tab:orange',linestyle='--',label=f'Average = {np.abs(np.mean(Z_adjusted, axis = 2)[0,0])}')
ax_12.set_title(f'First Corrected Chunk; Original Z; Ch = {ch}')
ax_12.legend()


Z_orig_averaged_down = np.mean(Z_orig_adjusted, axis = 2)

print(np.shape(Z_orig_averaged_down))






fig_13, ax_13 = plt.subplots(1)

ax_13.plot(Z_orig_averaged_down[ch],'.-')
ax_13.set_title(f'Averaging Every 32 Samples; Original; Ch = {ch}')
"""
"""

Z_adjusted_averaged = np.mean(Z_adjusted,axis=1)

print(np.shape(Z_adjusted_averaged))

fig_11, ax_11 = plt.subplots(1)

ax_11.plot(t_stack[0],Z_averaged_stacks[ch])
ax_11.plot(t_stack[0],Z_adjusted_averaged[ch])
ax_11.set_title(f'Averaging Adjsuted Chunks; Ch = {ch}')
"""
# Out:
# idx_start = 14
# (1003, 4866)
# (1003, 4880)
# 4864
# (1003, 4864)
# 152.0
# (1003, 32)
# [[ 0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j ...  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
#  [ 0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j ...  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
#  [ 1.81898940e-11-3.63797881e-11j -9.18961618e+03+2.76380265e+04j
#   -4.88862119e+03+4.18288244e+04j ... -6.26685001e+05-4.25139650e+04j
#   -4.05088581e+04+8.21679598e+03j -2.44812672e+04+1.20956598e+04j]
#  ...
#  [ 0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j ...  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
# ...

# %%
#print(np.shape(table_values))
#print(table_values)
t_LUT = np.arange(0,512,1)
table_freqs = np.abs(freqs[max_fft_idx])
table_values = np.exp(-1j*(2*np.pi*table_freqs*32/512)*t_LUT[:, np.newaxis]) #amplitude the same, clk division changes from 32 to 1; ω goes up by factor of 32
table_values = np.transpose(table_values)
#print(np.shape(table_values))

#find inactive channels
average = np.mean(table_values,axis=1)
#print(average)
unique, counts = np.unique(average,return_counts=True)
print(dict(zip(unique, counts)))
inactive_channels = np.argwhere(average == 1)[:,0] #an inactive channel averages down to 1

#remove inactive channels
table_values = np.delete(table_values, inactive_channels, axis=0)

print(np.shape(table_values))

print(table_values)

np.save('test_demod_ddc_20250203.npy',table_values)
# Out:
# {(0.003232731742066292+0.0017612275850958671j): 66, (1+0j): 937}
# (66, 512)
# [[ 1.        +0.j          0.63154311+0.77534076j -0.2023066 +0.97932224j
#   ...  0.71315487-0.70100651j  0.99390697+0.11022221j
#    0.54223533+0.84022666j]
#  [ 1.        +0.j          0.63154311+0.77534076j -0.2023066 +0.97932224j
#   ...  0.71315487-0.70100651j  0.99390697+0.11022221j
#    0.54223533+0.84022666j]
#  [ 1.        +0.j          0.63154311+0.77534076j -0.2023066 +0.97932224j
#   ...  0.71315487-0.70100651j  0.99390697+0.11022221j
#    0.54223533+0.84022666j]
#  ...
#  [ 1.        +0.j          0.63154311+0.77534076j -0.2023066 +0.97932224j
#   ...  0.71315487-0.70100651j  0.99390697+0.11022221j
#    0.54223533+0.84022666j]
#  [ 1.        +0.j          0.63154311+0.77534076j -0.2023066 +0.97932224j
#   ...  0.71315487-0.70100651j  0.99390697+0.11022221j
#    0.54223533+0.84022666j]
#  [ 1.        +0.j          0.63154311+0.77534076j -0.2023066 +0.97932224j
# ...

# %%
t_LUT = np.arange(0,32,1)

# %%
a = 1+1j
b = 3+3j

print(np.mean(np.array([a,b])))
# Out:
# (2+2j)

# %%
#to do:
#packet dropping: frame counter to track packets

# %% [markdown]
# ## testing readout on asu computer

# %%
# %matplotlib qt

# %%
ch = 21


t, I, Q = read_data('/home/cody/Documents/Stanford_Readout/data/time_streams/ts_toneinit_fcenter_5050.0_20250204112232_t_20250204113327.hd5')#ts_toneinit_fcenter_5050.0_20250201125701_t_20250201141648.hd5')
Z = I + 1j*Q

t_override = np.linspace(0,10,len(I[0]))

fig, ax = plt.subplots(1)

ax.plot(t_override, np.abs(Z[ch]))

# %%
ch = 10


t, I, Q = read_data('/home/cody/Documents/Stanford_Readout/data/time_streams/ts_toneinit_fcenter_5050.0_20250204114939_t_20250204115417.hd5')#ts_toneinit_fcenter_5050.0_20250201125701_t_20250201141648.hd5')
Z = I + 1j*Q

t_override = np.linspace(0,10,len(I[0]))

fig, ax = plt.subplots(1)

ax.plot(t_override, np.abs(Z[ch]))
ax.plot(t_override, I[ch])
ax.plot(t_override, Q[ch])
ax.set_title(f'ch = {ch}')
# Out:
# Text(0.5, 1.0, 'ch = 10')

# %%
ch = 10


t, I, Q = read_data('/home/cody/Documents/Stanford_Readout/data/time_streams/ts_toneinit_fcenter_5050.0_20250204114939_t_20250204120136.hd5')#ts_toneinit_fcenter_5050.0_20250201125701_t_20250201141648.hd5')
Z = I + 1j*Q

t_override = np.linspace(0,10,len(I[0]))

fig, ax = plt.subplots(1)

ax.plot(t_override, np.abs(Z[ch]))
ax.plot(t_override, I[ch])
ax.plot(t_override, Q[ch])

ax.set_title(f'ch = {ch}')

#ax.set_ylim([0,50000])
# Out:
# Text(0.5, 1.0, 'ch = 10')

# %%
ch = 21


t, I, Q = read_data('/home/cody/Documents/Stanford_Readout/data/time_streams/ts_toneinit_fcenter_5050.0_20250204124059_t_20250204125018.hd5')#ts_toneinit_fcenter_5050.0_20250201125701_t_20250201141648.hd5')
Z = I + 1j*Q

t_override = np.linspace(0,10,len(I[0]))

fig, ax = plt.subplots(1)

ax.plot(t_override, np.abs(Z[ch]))
ax.plot(t_override, I[ch])
ax.plot(t_override, Q[ch])

ax.set_ylim([0,50000])
# Out:
# (0.0, 50000.0)

# %%
ch = 21


t, I, Q = read_data('/home/cody/Documents/Stanford_Readout/data/time_streams/ts_toneinit_fcenter_5050.0_20250204124059_t_20250204130044.hd5')#ts_toneinit_fcenter_5050.0_20250201125701_t_20250201141648.hd5')
Z = I + 1j*Q

t_override = np.linspace(0,10,len(I[0]))

fig, ax = plt.subplots(1)

ax.plot(t_override, np.abs(Z[ch]))
ax.plot(t_override, I[ch])
ax.plot(t_override, Q[ch])

ax.set_ylim([0,50000])
# Out:
# (0.0, 50000.0)

# %%
data = np.load('/home/cody/Documents/Stanford_Readout/data/demod_luts/demod_lut_fcenter_5050.0_20250204130610_20250204131241.npy')

print(data)
# Out:
# [[1.+0.00000000e+00j 1.-1.03308807e-07j 1.-2.06617614e-07j ...
#   1.-5.25841826e-05j 1.-5.26874914e-05j 1.-5.27908003e-05j]
#  [1.+0.00000000e+00j 1.-1.03308807e-07j 1.-2.06617614e-07j ...
#   1.-5.25841826e-05j 1.-5.26874914e-05j 1.-5.27908003e-05j]
#  [1.+0.00000000e+00j 1.-1.03308807e-07j 1.-2.06617614e-07j ...
#   1.-5.25841826e-05j 1.-5.26874914e-05j 1.-5.27908003e-05j]
#  ...
#  [1.+0.00000000e+00j 1.-1.03308807e-07j 1.-2.06617614e-07j ...
#   1.-5.25841826e-05j 1.-5.26874914e-05j 1.-5.27908003e-05j]
#  [1.+0.00000000e+00j 1.-1.03308807e-07j 1.-2.06617614e-07j ...
#   1.-5.25841826e-05j 1.-5.26874914e-05j 1.-5.27908003e-05j]
#  [1.+0.00000000e+00j 1.-1.03308807e-07j 1.-2.06617614e-07j ...
#   1.-5.25841826e-05j 1.-5.26874914e-05j 1.-5.27908003e-05j]]

# %%
ch = 21


t, I, Q = read_data('/home/cody/Documents/Stanford_Readout/data/time_streams/ts_toneinit_fcenter_5050.0_20250204130610_t_20250204131925.hd5')#ts_toneinit_fcenter_5050.0_20250201125701_t_20250201141648.hd5')
Z = I + 1j*Q

t_override = np.linspace(0,10,len(I[0]))

fig, ax = plt.subplots(1)

ax.plot(t_override, np.abs(Z[ch]))
ax.plot(t_override, I[ch])
ax.plot(t_override, Q[ch])

ax.set_ylim([0,50000])
# Out:
# (0.0, 50000.0)

# %%
ch = 21


t, I, Q = read_data('/home/cody/Documents/Stanford_Readout/data/time_streams/ts_toneinit_fcenter_5050.0_20250204143923_t_20250204144951.hd5')#ts_toneinit_fcenter_5050.0_20250201125701_t_20250201141648.hd5')
Z = I + 1j*Q

t_override = np.linspace(0,10,len(I[0]))

fig, ax = plt.subplots(1)

ax.plot(t_override, np.abs(Z[ch]))
ax.plot(t_override, I[ch])
ax.plot(t_override, Q[ch])

ax.set_title(f'ch = {ch}')

ax.set_ylim([0,50000])
# Out:
# (0.0, 50000.0)

# %%
#fr off but demod on

ch = 27


t, I, Q = read_data('/home/cody/Documents/Stanford_Readout/data/time_streams/ts_toneinit_fcenter_5050.0_20250204143923_t_20250204150020.hd5')#ts_toneinit_fcenter_5050.0_20250201125701_t_20250201141648.hd5')
Z = I + 1j*Q

t_override = np.linspace(0,10,len(I[0]))

fig, ax = plt.subplots(1)

for i in [ch]:# range(len(Z)):
    ax.plot(t_override, np.abs(Z[i])) #- np.average(np.abs(Z[i])) + 300*i)
#ax.plot(t_override, I[ch])
#ax.plot(t_override, Q[ch])

ax.set_title(f'ch = {ch}')

ax.set_ylim([0,50000])
# Out:
# (0.0, 50000.0)

# %%
#fr off but demod on

ch = 27


t, I, Q = read_data('/home/cody/Documents/Stanford_Readout/data/time_streams/ts_toneinit_fcenter_5050.0_20250205113928_t_20250205115244.hd5')#ts_toneinit_fcenter_5050.0_20250201125701_t_20250201141648.hd5')
Z = I + 1j*Q

t_override = np.linspace(0,10,len(I[0]))

fig, ax = plt.subplots(1)

for i in [ch]:# range(len(Z)):
    ax.plot(t_override, np.abs(Z[i])) #- np.average(np.abs(Z[i])) + 300*i)
#ax.plot(t_override, I[ch])
#ax.plot(t_override, Q[ch])

ax.set_title(f'ch = {ch}')

#ax.set_ylim([0,50000])
# Out:
# Text(0.5, 1.0, 'ch = 27')

# %%
#fr off but demod on

ch = 21


t, I, Q = read_data('/home/cody/Documents/Stanford_Readout/data/time_streams/ts_toneinit_fcenter_5050.0_20250205113928_t_20250205115553.hd5')#ts_toneinit_fcenter_5050.0_20250201125701_t_20250201141648.hd5')
Z = I + 1j*Q

t_override = np.linspace(0,10,len(I[0]))

fig, ax = plt.subplots(1)

for i in [ch]:# range(len(Z)):
    ax.plot(t_override, np.abs(Z[i])) #- np.average(np.abs(Z[i])) + 300*i)
#ax.plot(t_override, I[ch])
#ax.plot(t_override, Q[ch])

ax.set_title(f'ch = {ch}')

#ax.set_ylim([0,50000])
# Out:
# Text(0.5, 1.0, 'ch = 21')

# %%
#fr off but demod on

ch = 21


t, I, Q = read_data('/home/cody/Documents/Stanford_Readout/data/time_streams/ts_toneinit_fcenter_5050.0_20250205115750_t_20250205120223.hd5')#ts_toneinit_fcenter_5050.0_20250201125701_t_20250201141648.hd5')
Z = I + 1j*Q

t_override = np.linspace(0,10,len(I[0]))

fig, ax = plt.subplots(1)

for i in [ch]:# range(len(Z)):
    ax.plot(t_override, np.abs(Z[i])) #- np.average(np.abs(Z[i])) + 300*i)
#ax.plot(t_override, I[ch])
#ax.plot(t_override, Q[ch])

ax.set_title(f'ch = {ch}')

#ax.set_ylim([0,50000])
# Out:
# Text(0.5, 1.0, 'ch = 21')

# %%
#fr off but demod on

ch = 21


t, I, Q = read_data('/home/cody/Documents/Stanford_Readout/data/time_streams/ts_toneinit_fcenter_5050.0_20250205115750_t_20250205120425.hd5')#ts_toneinit_fcenter_5050.0_20250201125701_t_20250201141648.hd5')
Z = I + 1j*Q

t_override = np.linspace(0,10,len(I[0]))

fig, ax = plt.subplots(1)

for i in [ch]:# range(len(Z)):
    ax.plot(t_override, np.abs(Z[i])) #- np.average(np.abs(Z[i])) + 300*i)
#ax.plot(t_override, I[ch])
#ax.plot(t_override, Q[ch])

ax.set_title(f'ch = {ch}')

#ax.set_ylim([0,50000])
# Out:
# Text(0.5, 1.0, 'ch = 21')

# %%
#fr off but demod on

ch = 21


t, I, Q = read_data('/home/cody/Documents/Stanford_Readout/data/time_streams/ts_toneinit_fcenter_5050.0_20250205115750_t_20250205120733.hd5')#ts_toneinit_fcenter_5050.0_20250201125701_t_20250201141648.hd5')
Z = I + 1j*Q

t_override = np.linspace(0,10,len(I[0]))

fig, ax = plt.subplots(1)

for i in [ch]:# range(len(Z)):
    ax.plot(t_override, np.abs(Z[i])) #- np.average(np.abs(Z[i])) + 300*i)
#ax.plot(t_override, I[ch])
#ax.plot(t_override, Q[ch])

ax.set_title(f'ch = {ch}')

#ax.set_ylim([0,50000])
# Out:
# Text(0.5, 1.0, 'ch = 21')

# %%
#fr off but demod on

ch = 21


t, I, Q = read_data('/home/cody/Documents/Stanford_Readout/data/time_streams/ts_toneinit_fcenter_5050.0_20250205115750_t_20250205120927.hd5')#ts_toneinit_fcenter_5050.0_20250201125701_t_20250201141648.hd5')
Z = I + 1j*Q

t_override = np.linspace(0,10,len(I[0]))

fig, ax = plt.subplots(1)

for i in [ch]:# range(len(Z)):
    ax.plot(t_override, np.abs(Z[i])) #- np.average(np.abs(Z[i])) + 300*i)
#ax.plot(t_override, I[ch])
#ax.plot(t_override, Q[ch])

ax.set_title(f'ch = {ch}')

ax.set_ylim([52000,56000])
# Out:
# (52000.0, 56000.0)

# %%
#fr off but demod on

ch = 21


t, I, Q = read_data('/home/cody/Documents/Stanford_Readout/data/time_streams/ts_toneinit_fcenter_5050.0_20250205124112_t_20250205124603.hd5')#ts_toneinit_fcenter_5050.0_20250201125701_t_20250201141648.hd5')
Z = I + 1j*Q

t_override = np.linspace(0,10,len(I[0]))

fig, ax = plt.subplots(1)

for i in [ch]:# range(len(Z)):
    ax.plot(t_override, np.abs(Z[i])) #- np.average(np.abs(Z[i])) + 300*i)
#ax.plot(t_override, I[ch])
#ax.plot(t_override, Q[ch])

ax.set_title(f'ch = {ch}')

#ax.set_ylim([52000,56000])
# Out:
# Text(0.5, 1.0, 'ch = 21')

# %%
#fr off but demod on

ch = 21


t, I, Q = read_data('/home/cody/Documents/Stanford_Readout/data/time_streams/ts_toneinit_fcenter_5050.0_20250205124112_t_20250205124926.hd5')#ts_toneinit_fcenter_5050.0_20250201125701_t_20250201141648.hd5')
Z = I + 1j*Q

t_override = np.linspace(0,10,len(I[0]))

fig, ax = plt.subplots(1)

for i in [ch]:# range(len(Z)):
    ax.plot(t_override, np.abs(Z[i])) #- np.average(np.abs(Z[i])) + 300*i)
#ax.plot(t_override, I[ch])
#ax.plot(t_override, Q[ch])

ax.set_title(f'ch = {ch}')

#ax.set_ylim([52000,56000])
# Out:
# Text(0.5, 1.0, 'ch = 21')

# %%
#fr off but demod on

ch = 21


t, I, Q = read_data('/home/cody/Documents/Stanford_Readout/data/time_streams/ts_toneinit_fcenter_5050.0_20250205125710_t_20250205134813.hd5')#ts_toneinit_fcenter_5050.0_20250205125710_t_20250205130812.hd5')#ts_toneinit_fcenter_5050.0_20250201125701_t_20250201141648.hd5')
Z = I + 1j*Q

t_override = np.linspace(0,10,len(I[0]))

fig, ax = plt.subplots(1)
fig_2, ax_2 = plt.subplots(1)
fig_3, ax_3 = plt.subplots(1)


for i in [ch]: #range(len(Z)):
    ax.plot(t_override, np.abs(Z[i]))#- np.average(np.abs(Z[i])) + 300*i)
    
    n = len(Z[i])
    timestep = np.average(np.diff(t_override))
    freq = np.fft.fftfreq(n, d=timestep)
    ax_2.stem(freq, np.abs(fft(np.abs(Z[i])- np.average(np.abs(Z[i])))))
    ax_3.plot(freq, np.abs(fft(np.abs(Z[i])- np.average(np.abs(Z[i])))))
    
    #ax.plot(t_override, I[ch])
    #ax.plot(t_override, Q[ch])

ax.set_title(f'ch = {ch}')

#ax.set_ylim([52000,56000])
# Out:
# Text(0.5, 1.0, 'ch = 21')
